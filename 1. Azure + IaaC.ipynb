# %% [markdown]
# # Azure Cloud
#
# Панель управления облаком через браузер - https://portal.azure.com/#home
#
# ### Создаем виртуальную машину
#
# "Создать ресурс" -> "Ubuntu Server 18.04 LTS"
#
# * **ВАЖНО** - укажите правильную подписку, созданную специально для этого курса!
# * Группа ресурсов - это специальная группа, к которой будут подключены все штуки, которые вы будете создавать в облаке. Для работы вам будет достаточно пользоваться одной группой ресурсов для всего. Создайте новую (или если уже есть, выберете существующую)
# * Подробности об экземпляре - можно выдать любое имя машины и оставить остальные параметры как есть
# * Учетная запись администратора - особой разницы между ключем SSH и паролем нет - выбирайте любой, какой больше нравится (не забудьте пароль, если выбрали его)
# * Входящие порты - оставьте только 22. Далее мы еще узнаем, как получить безопасный доступ к машине
#
# -- Далее --
#
# * Диск лучше оставить SSD
# * Если на машине будете работать с большими объемами, то можно подключить новый диск
#
# -- Далее --
#
# * Сетевые подключения - оставляем как есть
#
# -- Далее --
#
# * Управление - оставлякм как есть
#
# -- Далее --
#
# * Дополнительно - оставляем как есть
#
# -- Далее --
#
# * Теги - оставляем как есть
#
# -- Далее --
#
# * СОЗДАТЬ!
#
# Если у вас создавался новый SSH ключ, то скачайте его и положите в `~/.ssh`, после чего
# ```bash
# sudo chmod 600 ~/.ssh/KEY.pem
# eval $(ssh-agent -s)
# ssh-add ~/.ssh/KEY.pem
# ```
#
# После того, как машина развернется в облаке, можно к ней подключится. На странице ресурса необходимо получить "Общедоступный IP-адрес".
#
# ```bash
# ssh azureuser@1.2.3.4
# ```
#
# Чтобы получить права администратора, достаточно выполнить
#
# ```bash
# sudo su
# ```
#
# Поздравляю, это ваша личная виртуальная машина в облаке!

# %% [markdown]
# ### Подключаем диски
#
# Если вы добавляли диск на машину, то он автоматически не примонтируется к операционной системе. Для того, чтобы им воспользоваться нужно
#
# Проверить, что блочное устройство подключено:
#
# ```bash
# $ sudo fdisk -l
#
# ...
# Disk /dev/sda: 1 TiB, 1099511627776 bytes, 2147483648 sectors
# Units: sectors of 1 * 512 = 512 bytes
# Sector size (logical/physical): 512 bytes / 4096 bytes
# I/O size (minimum/optimal): 4096 bytes / 4096 bytes
# ```
#
# Выделить раздел на устройстве
#
# ```bash
# $ sudo parted /dev/sda --script mklabel gpt mkpart primary ext4 0% 100%
# $ sudo mkfs -t ext4 /dev/sda1
# $ sudo fdisk -l
#
# ...
# Device     Start        End    Sectors  Size Type
# /dev/sda1   2048 2147481599 2147479552 1024G Linux filesystem
# ```
#
# Примонтировать
#
# ```bash
# $ sudo mkdir /data
# $ sudo mount /dev/sda1 /data
# ```
#
# Ваш диск теперь должен быть в `/data`

# %% [markdown]
# ### Ставим инструменты для работы
#
# Если вы планирете заниматься на машине анализом данных, то скорее всего это будет удобнее делать через Jupyter Notebook.
#
# Ставим библиотеку
#
# ```bash
# # get link from this site - https://www.anaconda.com/distribution/
#
# wget https://repo.anaconda.com/archive/Anaconda3-2020.11-Linux-x86_64.sh -O install-conda.sh
# chmod +x install-conda.sh
# ./install-conda.sh
#
# # add conda to PATH
#
# eval "$(/home/azureuser/anaconda3/bin/conda shell.bash hook)"
# conda init
# ```
#
# Запускаем Jupyter. Чтобы он продолжил работать даже после того, как вы закроете терминал, используйте `tmux`. Подсказки по использованию tmux - https://gist.github.com/MohamedAlaa/2961058 .
#
# ```bash
# tmux new -s jupyter
# jupyter notebook --ip=0.0.0.0 --NotebookApp.token=
# ```

# %% [markdown]
# ### Подключаемся через Proxy
#
# В целях безопасности, никакого доступа к машине, кроме как по SSH, нет. Чтобы получить доступ до ноутбука (или до любых других сетевых компонентов на машине) нужно подключить Proxy через SSH.
#
# Для этого поднимаем SOCKS proxy
#
# ```bash
# ssh -4 -D <local-port> <user>@<remotehost> -N
# ```
#
# * -D <local-port> указывает на каком порту на **локальной машине** открыть прокси
# * -N - не открывать shell на удаленной машине - только прокси
# * -4 - использовать IPv4
#
# После устанавливаем расширение для Chrome Proxy SwitchyOmega - https://chrome.google.com/webstore/detail/proxy-switchyomega/padekgcemlokbadohgkifijomclgjgif?hl=en-GB
#
# Внутри Omega нужно настроить
#
# * Proxy - SOCKS5 | localhost | 5555 - ходить в **локалхост** за проксей
# * Auto switch - Host wildcard | 10.0.0.* | proxy - на всех адресах совпадающих с паттерном использовать прокси
#
# Note: 10.0.0.* - это адреса внутренней сети ваших машин в облаке. Это можно проверить в панели управления.
#
# Пример моей настройки прокси
#
# <img src="https://raw.githubusercontent.com/ADKosm/lsml-2021-public/main/imgs/proxy-1.png">
# <img src="https://raw.githubusercontent.com/ADKosm/lsml-2021-public/main/imgs/proxy-2.png">

# %% [markdown]
# ### Примерная схема того, как работает доступ до облака через прокси
#
# <img src="https://raw.githubusercontent.com/ADKosm/lsml-2021-public/main/imgs/proxy-azure.png">

# %% [markdown]
# # AZ CLI
#
# Каждый раз руками тыкать на все кнопки в интерфейсе - это неудобно. Для того, чтобы работать с облаком в более автоматическом режиме, Azure предоставляет утилиту командной строки `az`.
#
# Установим ее и посмотрим, как она работает.

# %%
! wget https://aka.ms/InstallAzureCLIDeb -O - | sudo bash
# Out:
# --2021-01-13 12:18:12--  https://aka.ms/InstallAzureCLIDeb
# Resolving aka.ms (aka.ms)... 23.32.88.21
# Connecting to aka.ms (aka.ms)|23.32.88.21|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://azurecliprod.blob.core.windows.net/$root/deb_install.sh [following]
# --2021-01-13 12:18:12--  https://azurecliprod.blob.core.windows.net/$root/deb_install.sh
# Resolving azurecliprod.blob.core.windows.net (azurecliprod.blob.core.windows.net)... 13.88.145.64
# Connecting to azurecliprod.blob.core.windows.net (azurecliprod.blob.core.windows.net)|13.88.145.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4309 (4.2K) [text/x-sh]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   4.21K  --.-KB/s    in 0s
#
# 2021-01-13 12:18:13 (1.08 GB/s) - written to stdout [4309/4309]
#
# Hit:1 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:3 http://security.ubuntu.com/ubuntu focal-security InRelease [109 kB]
# Hit:4 https://packages.microsoft.com/repos/azure-cli focal InRelease
# Get:5 http://archive.ubuntu.com/ubuntu focal-backports InRelease [101 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [952 kB]
# Fetched 1,275 kB in 1s (1,551 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gnupg is already the newest version (2.2.19-3ubuntu2).
# lsb-release is already the newest version (11.1.0ubuntu2).
# curl is already the newest version (7.68.0-1ubuntu2.4).
# apt-transport-https is already the newest version (2.0.2ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# Hit:1 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:3 https://packages.microsoft.com/repos/azure-cli focal InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:5 http://security.ubuntu.com/ubuntu focal-security InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# azure-cli is already the newest version (2.17.1-1~focal).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %%
# %%bash
#
# az --version
# Out:
# azure-cli                         2.17.1
#
# core                              2.17.1
# telemetry                          1.0.6
#
# Python location '/opt/az/bin/python3'
# Extensions directory '/home/jovyan/.azure/cliextensions'
#
# Python (Linux) 3.6.10 (default, Dec 31 2020, 08:28:47)
# [GCC 9.3.0]
#
# Legal docs and information: aka.ms/AzureCliLegal
#
#
# Your CLI is up-to-date.
#
# Please let us know how we are doing: https://aka.ms/azureclihats
# and let us know if you're interested in trying out our newest features: https://aka.ms/CLIUXstudy

# %%
! az login
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CP8GNTS3F to authenticate.
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "21f26c24-0793-4b07-a73d-563cd2ec235f",
#     "id": "7d1225ca-27cc-40b7-8036-c62a48072ba8",
#     "isDefault": true,
#     "managedByTenants": [],
#     "name": "Спонсорское предложение Microsoft Azure 2",
#     "state": "Enabled",
#     "tenantId": "21f26c24-0793-4b07-a73d-563cd2ec235f",
#     "user": {
#       "name": "adkosmachev@edu.hse.ru",
#       "type": "user"
#     }
#   }
# ]

# %%
# %%writefile password-file.txt
# # Здесь должен быть ваш пароль
# Out:
# Overwriting password-file.txt

# %%
! cat password-file.txt | head -c 1
# Out:
# A

# %%
! az login -u adkosmachev@edu.hse.ru -p $(cat password-file.txt)
# Out:
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "21f26c24-0793-4b07-a73d-563cd2ec235f",
#     "id": "7d1225ca-27cc-40b7-8036-c62a48072ba8",
#     "isDefault": true,
#     "managedByTenants": [],
#     "name": "Спонсорское предложение Microsoft Azure 2",
#     "state": "Enabled",
#     "tenantId": "21f26c24-0793-4b07-a73d-563cd2ec235f",
#     "user": {
#       "name": "adkosmachev@edu.hse.ru",
#       "type": "user"
#     }
#   }
# ]

# %%
! az account list
# Out:
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "21f26c24-0793-4b07-a73d-563cd2ec235f",
#     "id": "7d1225ca-27cc-40b7-8036-c62a48072ba8",
#     "isDefault": true,
#     "managedByTenants": [],
#     "name": "Спонсорское предложение Microsoft Azure 2",
#     "state": "Enabled",
#     "tenantId": "21f26c24-0793-4b07-a73d-563cd2ec235f",
#     "user": {
#       "name": "adkosmachev@edu.hse.ru",
#       "type": "user"
#     }
#   }
# ]

# %% [markdown]
# С помощью этого инструмента из командной строки можно проводить любые манипуляции над ресурсами в облаке. Однако почти всегда элементы в облаке требуют большого числа параметров и задавать их в одной команде очень неудобно. Например так выглядит документация по команде `az vm create`, которая создает новую виртуальную машину - [смотри в доке](https://docs.microsoft.com/en-us/cli/azure/vm?view=azure-cli-latest#az_vm_create).
#
# ```bash
# az vm create --name
#              --resource-group
#              [--accelerated-networking {false, true}]
#              [--admin-password]
#              [--admin-username]
#              [--asgs]
#              [--assign-identity]
#              [--attach-data-disks]
#              [--attach-os-disk]
#              [--authentication-type {all, password, ssh}]
#              [--availability-set]
#              [--boot-diagnostics-storage]
#              [--computer-name]
#              [--custom-data]
#              [--data-disk-caching]
#              [--data-disk-encryption-sets]
#              [--data-disk-sizes-gb]
#              [--enable-agent {false, true}]
#              [--enable-auto-update {false, true}]
#              [--encryption-at-host {false, true}]
#              [--ephemeral-os-disk {false, true}]
#              [--eviction-policy {Deallocate, Delete}]
#              [--generate-ssh-keys]
#              [--host]
#              [--host-group]
#              [--image]
#              [--license-type {None, RHEL_BYOS, SLES_BYOS, Windows_Client, Windows_Server}]
#              [--location]
#              [--max-price]
#              [--nics]
#              [--no-wait]
#              [--nsg]
#              [--nsg-rule {NONE, RDP, SSH}]
#              [--os-disk-caching {None, ReadOnly, ReadWrite}]
#              [--os-disk-encryption-set]
#              [--os-disk-name]
#              [--os-disk-size-gb]
#              [--os-type {linux, windows}]
#              [--patch-mode {AutomaticByOS, AutomaticByPlatform, Manual}]
#              [--plan-name]
#              [--plan-product]
#              [--plan-promotion-code]
#              [--plan-publisher]
#              [--ppg]
#              [--priority {Low, Regular, Spot}]
#              [--private-ip-address]
#              [--public-ip-address]
#              [--public-ip-address-allocation {dynamic, static}]
#              [--public-ip-address-dns-name]
#              [--public-ip-sku {Basic, Standard}]
#              [--role]
#              [--scope]
#              [--secrets]
#              [--size]
#              [--specialized {false, true}]
#              [--ssh-dest-key-path]
#              [--ssh-key-values]
#              [--storage-account]
#              [--storage-container-name]
#              [--storage-sku]
#              [--subnet]
#              [--subnet-address-prefix]
#              [--subscription]
#              [--tags]
#              [--ultra-ssd-enabled {false, true}]
#              [--use-unmanaged-disk]
#              [--validate]
#              [--vmss]
#              [--vnet-address-prefix]
#              [--vnet-name]
#              [--workspace]
#              [--zone {1, 2, 3}]
# ```
#
# Поэтому мы с вами пойдем немного более продвинутым путем.

# %% [markdown]
# # Terraform
#
# Для удобной автоматизации задач по развертке ресурсов в облаке существуют различные Infrastructure-as-a-Code решения. В рамках этой парадигмы пользователю необходимо написать определенную конфигурацию облачных ресурсов, а специальный инструмент за пользователя воссоздаст необходимые элементы.
#
# Для Azure существует как минимум два популярных решения такого рода - Шаблоны Azure Resource Manager (ARM) и Terraform (подробнее можно почитать [в документации Azure](https://docs.microsoft.com/ru-ru/dotnet/architecture/cloud-native/infrastructure-as-code) ). Мы с вами будем использовать Terraform, как более удобный и универсальный инструмент автоматизации.
#
# Более детально про язык конфигурации HCL, используемый в Terraform, и про сам инструмент можно прочитать на [официальном сайте разработчиков](https://www.terraform.io/). Мы рассмотрим основные возможности.

# %% [markdown]
# ### Начало работы

# %%
# Скачиваем инструмент и кладем его в /usr/bin.

! wget https://releases.hashicorp.com/terraform/0.14.3/terraform_0.14.3_linux_amd64.zip -O terra.zip
! unzip terra.zip
! cp terraform /usr/bin/
# Out:
# --2021-01-13 12:22:56--  https://releases.hashicorp.com/terraform/0.14.3/terraform_0.14.3_linux_amd64.zip
# Resolving releases.hashicorp.com (releases.hashicorp.com)... 151.101.1.183, 151.101.65.183, 151.101.129.183, ...
# Connecting to releases.hashicorp.com (releases.hashicorp.com)|151.101.1.183|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33647270 (32M) [application/zip]
# Saving to: ‘terra.zip’
#
# terra.zip           100%[===================>]  32.09M  22.1MB/s    in 1.4s
#
# 2021-01-13 12:22:58 (22.1 MB/s) - ‘terra.zip’ saved [33647270/33647270]
#
# Archive:  terra.zip
#   inflating: terraform

# %%
! terraform --help
# Out:
# Usage: terraform [global options] <subcommand> [args]
#
# The available commands for execution are listed below.
# The primary workflow commands are given first, followed by
# less common or more advanced commands.
#
# Main commands:
#   init          Prepare your working directory for other commands
#   validate      Check whether the configuration is valid
#   plan          Show changes required by the current configuration
#   apply         Create or update infrastructure
#   destroy       Destroy previously-created infrastructure
#
# All other commands:
#   console       Try Terraform expressions at an interactive command prompt
#   fmt           Reformat your configuration in the standard style
#   force-unlock  Release a stuck lock on the current workspace
#   get           Install or upgrade remote Terraform modules
#   graph         Generate a Graphviz graph of the steps in an operation
#   import        Associate existing infrastructure with a Terraform resource
#   login         Obtain and save credentials for a remote host
#   logout        Remove locally-stored credentials for a remote host
#   output        Show output values from your root module
#   providers     Show the providers required for this configuration
#   refresh       Update the state to match remote systems
#   show          Show the current state or a saved plan
#   state         Advanced state management
#   taint         Mark a resource instance as not fully functional
#   untaint       Remove the 'tainted' state from a resource instance
#   version       Show the current Terraform version
#   workspace     Workspace management
#
# Global options (use these before the subcommand, if any):
#   -chdir=DIR    Switch to a different working directory before executing the
#                 given subcommand.
#   -help         Show this help output, or the help for a specified subcommand.
#   -version      An alias for the "version" subcommand.

# %%
# Работать будем из новой директории

! mkdir -p my-first-cloud

# %cd my-first-cloud/
# Out:
# /home/jovyan/my-first-cloud

# %%
! pwd
! ls
# Out:
# /home/jovyan/my-first-cloud

# %%
! terraform init
# Out:
# Terraform initialized in an empty directory!
#
# The directory has no Terraform configuration files. You may begin working
# with Terraform immediately by creating Terraform configuration files.

# %% [markdown]
# В файлах с расширением `tf` описываются ресурсы, которые необходимо создать в облаке. Какие ресурсы вообще доступны и какие параметры они требуют можно посмотреть в [официальной документации Terraform для Azure](https://registry.terraform.io/providers/hashicorp/azurerm/latest/docs).

# %%
# %%writefile common.tf
#
# provider "azurerm" {
#   # Провайдер, с которым будем работать. В данном случае - Azure
#   version = "=2.40.0"
#   features {}
# }
#
# # Группа ресурсов. К ней будут линковаться все осталные ресурсы
# resource "azurerm_resource_group" "lsml_rg" {
#   name = "lsml-resource-group"
#   location = "westus"
# }
#
# # Виртуальная сеть внутри облака
# resource "azurerm_virtual_network" "lsml_vn" {
#   name = "lsml-vitrual-network"
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#   location = azurerm_resource_group.lsml_rg.location
#   address_space = ["10.0.0.0/16"]   # Пул адресов внутри сети
# }
# Out:
# Writing common.tf

# %%
! terraform init
# Out:
# Initializing the backend...
#
# Initializing provider plugins...
# - Finding hashicorp/azurerm versions matching "2.40.0"...
# - Installing hashicorp/azurerm v2.40.0...
# - Installed hashicorp/azurerm v2.40.0 (signed by HashiCorp)
#
# Terraform has created a lock file .terraform.lock.hcl to record the provider
# selections it made above. Include this file in your version control repository
# so that Terraform can guarantee to make the same selections by default when
# you run "terraform init" in the future.
#
#
# Warning: Version constraints inside provider configuration blocks are deprecated
#
#   on common.tf line 4, in provider "azurerm":
#    4:   version = "=2.40.0"
#
# Terraform 0.13 and earlier allowed provider version constraints inside the
# provider configuration block, but that is now deprecated and will be removed
# in a future version of Terraform. To silence this warning, move the provider
# version constraint into the required_providers block.
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %%
! ls -la
# Out:
# total 20
# drwxr-xr-x  3 root root 4096 Jan 13 12:26 .
# drwxrwxr-x 11 1001 1002 4096 Jan 13 12:25 ..
# -rw-r--r--  1 root root  723 Jan 13 12:26 common.tf
# drwxr-xr-x  3 root root 4096 Jan 13 12:26 .terraform
# -rwxrwxrwx  1 root root 1035 Jan 13 12:26 .terraform.lock.hcl

# %% [markdown]
# Удалим все ресурсы в облаке через интерфейс. После этого запускаем команду
# ```bash
# terraform apply
# ```
#
# Она посмотрит на конфигурацию, посмотрим на текущее состояние дел в облаке и составит план работ.
# Если план вас устраивает, то необходимо в явном виде согласиться с применением этого плана. По этой причине лучше запускать этот инструмент из командной строки, а не из Jupyter Notebook. Мы будем использовать трюк пайплайнами в Bash. Про то, почему это работает и как этим пользоваться - в следующий раз.
#
# Note: если Terraform жалуется на авторизацию, запустите `az login` перед terraform.

# %%
! terraform plan  # Посмотреть только план, без реальных изменений
# Out:
# An execution plan has been generated and is shown below.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # azurerm_resource_group.lsml_rg will be created
#   + resource "azurerm_resource_group" "lsml_rg" {
#       + id       = (known after apply)
#       + location = "westus"
#       + name     = "lsml-resource-group"
#     }
#
#   # azurerm_virtual_network.lsml_vn will be created
#   + resource "azurerm_virtual_network" "lsml_vn" {
#       + address_space         = [
#           + "10.0.0.0/16",
#         ]
#       + guid                  = (known after apply)
#       + id                    = (known after apply)
#       + location              = "westus"
#       + name                  = "lsml-vitrual-network"
#       + resource_group_name   = "lsml-resource-group"
#       + subnet                = (known after apply)
#       + vm_protection_enabled = false
#     }
#
# Plan: 2 to add, 0 to change, 0 to destroy.
#
# Warning: Version constraints inside provider configuration blocks are deprecated
#
#   on common.tf line 4, in provider "azurerm":
#    4:   version = "=2.40.0"
#
# Terraform 0.13 and earlier allowed provider version constraints inside the
# provider configuration block, but that is now deprecated and will be removed
# in a future version of Terraform. To silence this warning, move the provider
# version constraint into the required_providers block.
#
#
# ------------------------------------------------------------------------
#
# Note: You didn't specify an "-out" parameter to save this plan, so Terraform
# can't guarantee that exactly these actions will be performed if
# "terraform apply" is subsequently run.

# %%
! echo "yes" | terraform apply  # Строим и применяем план
# Out:
# An execution plan has been generated and is shown below.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # azurerm_resource_group.lsml_rg will be created
#   + resource "azurerm_resource_group" "lsml_rg" {
#       + id       = (known after apply)
#       + location = "westus"
#       + name     = "lsml-resource-group"
#     }
#
#   # azurerm_virtual_network.lsml_vn will be created
#   + resource "azurerm_virtual_network" "lsml_vn" {
#       + address_space         = [
#           + "10.0.0.0/16",
#         ]
#       + guid                  = (known after apply)
#       + id                    = (known after apply)
#       + location              = "westus"
#       + name                  = "lsml-vitrual-network"
#       + resource_group_name   = "lsml-resource-group"
#       + subnet                = (known after apply)
#       + vm_protection_enabled = false
#     }
#
# Plan: 2 to add, 0 to change, 0 to destroy.
#
#
# Warning: Version constraints inside provider configuration blocks are deprecated
#
#   on common.tf line 4, in provider "azurerm":
#    4:   version = "=2.40.0"
#
# Terraform 0.13 and earlier allowed provider version constraints inside the
# provider configuration block, but that is now deprecated and will be removed
# in a future version of Terraform. To silence this warning, move the provider
# version constraint into the required_providers block.
#
# Do you want to perform these actions?
#   Terraform will perform the actions described above.
#   Only 'yes' will be accepted to approve.
#
#   Enter a value:
# azurerm_resource_group.lsml_rg: Creating...
# azurerm_resource_group.lsml_rg: Creation complete after 3s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group]
# azurerm_virtual_network.lsml_vn: Creating...
# azurerm_virtual_network.lsml_vn: Still creating... [10s elapsed]
# azurerm_virtual_network.lsml_vn: Creation complete after 14s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network]
#
# Apply complete! Resources: 2 added, 0 changed, 0 destroyed.

# %% [markdown]
# Смотрим в интерфейс Azure в браузере - там должны были появиться наши ресурсы!
#
# ### Создание виртуальных машин в облаке
#
# Создадим что-то более интересное в облаке.

# %%
! ls -la
# Out:
# total 24
# drwxr-xr-x  3 root root 4096 Jan 13 12:28 .
# drwxrwxr-x 12 1001 1002 4096 Jan 13 12:29 ..
# -rw-r--r--  1 root root  723 Jan 13 12:26 common.tf
# drwxr-xr-x  3 root root 4096 Jan 13 12:26 .terraform
# -rwxrwxrwx  1 root root 1035 Jan 13 12:26 .terraform.lock.hcl
# -rw-r--r--  1 root root 2229 Jan 13 12:28 terraform.tfstate

# %%
# %%writefile common.tf
#
# # Тут будут описаны общие ресурсы
#
# provider "azurerm" {
#   # Провайдер, с которым будем работать. В данном случае - Azure
#   version = "=2.40.0"
#   features {}
# }
#
# # Группа ресурсов. К ней будут линковаться все осталные ресурсы
# resource "azurerm_resource_group" "lsml_rg" {
#   name = "lsml-resource-group"
#   location = "westus"
# }
#
# # Виртуальная сеть внутри облака
# resource "azurerm_virtual_network" "lsml_vn" {
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#   location = azurerm_resource_group.lsml_rg.location
#
#   name = "lsml-vitrual-network"
#
#   address_space = ["10.0.0.0/16"]
#   # Пул адресов внутри сети
# }
#
# # Виртуальная подсеть внутри облака
# resource "azurerm_subnet" "lsml_subnet" {
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#   virtual_network_name = azurerm_virtual_network.lsml_vn.name
#
#   name = "internal"
#
#   address_prefixes = ["10.0.2.0/24"]
# }
# Out:
# Overwriting common.tf

# %%
# %%writefile vm.tf
# # Здесь описываем ресурсы, необходимые для работы машины
#
# # Публичный адрес машины
# resource "azurerm_public_ip" "lsml_pub_ip" {
#   location = azurerm_resource_group.lsml_rg.location
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#
#   name = "lsml-public-ip"
#
#   allocation_method = "Dynamic" # Выдаем динамический ip
#   idle_timeout_in_minutes = 30
#   domain_name_label = "alexlsmlmachine" # Для удобства можно использовать DNS имя
# }
#
# # Сетевой интерфейс для нашей машины
# resource "azurerm_network_interface" "lsml_ni" {
#   location = azurerm_resource_group.lsml_rg.location
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#
#   name = "lsml-nic"
#
#   ip_configuration {
#     name = "internal"
#     private_ip_address_allocation = "Dynamic"
#     subnet_id = azurerm_subnet.lsml_subnet.id
#     public_ip_address_id = azurerm_public_ip.lsml_pub_ip.id
#   }
# }
#
# # Сама виртуальная машина
# resource "azurerm_virtual_machine" "lsml_vm" {
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#   location = azurerm_resource_group.lsml_rg.location
#
#   name = "lsml-machine"
#
#   vm_size = "Standard_F2" # 2 CPU 4 GB
#   # Какие размеры вообще бывают - https://azure.microsoft.com/en-us/pricing/details/virtual-machines/series/
#
#   network_interface_ids = [
#     azurerm_network_interface.lsml_ni.id,
#     # Подключаем к сети
#   ]
#
#   storage_image_reference {
#     # Используем образ Ubuntu 16.04
#     publisher = "Canonical"
#     offer = "UbuntuServer"
#     sku = "16.04-LTS"
#     version = "latest"
#   }
#
#   os_profile {
#     computer_name = "hostname"
#     admin_username = "azureuser" # Пользователь и его пароль
#     admin_password = "Password1234!"
#   }
#   os_profile_linux_config {
#     disable_password_authentication = false
#     ssh_keys {
#       path = "/home/azureuser/.ssh/authorized_keys"
#       key_data = file("~/id_rsa.pub") # Можем указать наш ключ, как ключ для авторизации на машине
#     }
#   }
#
#   delete_os_disk_on_termination = true
#   storage_os_disk {
#     name = "main-disk"
#     caching = "ReadWrite"
#     create_option = "FromImage"
#     managed_disk_type = "Standard_LRS"
#     disk_size_gb = "200" # Указываем какой использовать основной жесткий диск и его размер
#   }
# }
#
#
# # Сохраним несколько важных значений в output. Их можно будет потом использовать для наших целей
#
# data "azurerm_public_ip" "lsml_public_ip" {
#   name = azurerm_public_ip.lsml_pub_ip.name
#   resource_group_name = azurerm_virtual_machine.lsml_vm.resource_group_name
# }
#
# output "public_domain" {
#   # Домен нашего сервера
#   value = "${azurerm_public_ip.lsml_pub_ip.domain_name_label}.${azurerm_resource_group.lsml_rg.location}.cloudapp.azure.com"
# }
#
# output "public_ip" {
#   # Публичный ip нашего сервера
#   value = data.azurerm_public_ip.lsml_public_ip.ip_address
# }
#
# output "private_ip" {
#   # Приватный ip нашего сервера
#   value = azurerm_network_interface.lsml_ni.private_ip_address
# }
# Out:
# Writing vm.tf

# %% [markdown]
# Terraform работает на уровне директории. Все файлы с расширением `tf` он воспринимает как одну большую конфигурацию.
#
# Запускаем команду и развертываем все описанные ресурсы в облаке.

# %%
! echo "yes" | terraform apply
# Out:
# azurerm_resource_group.lsml_rg: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group]
# azurerm_virtual_network.lsml_vn: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network]
#
# An execution plan has been generated and is shown below.
# Resource actions are indicated with the following symbols:
#   + create
#  <= read (data resources)
#
# Terraform will perform the following actions:
#
#   # data.azurerm_public_ip.lsml_public_ip will be read during apply
#   # (config refers to values not yet known)
#  <= data "azurerm_public_ip" "lsml_public_ip"  {
#       + allocation_method       = (known after apply)
#       + domain_name_label       = (known after apply)
#       + fqdn                    = (known after apply)
#       + id                      = (known after apply)
#       + idle_timeout_in_minutes = (known after apply)
#       + ip_address              = (known after apply)
#       + ip_version              = (known after apply)
#       + location                = (known after apply)
#       + name                    = "lsml-public-ip"
#       + resource_group_name     = "lsml-resource-group"
#       + reverse_fqdn            = (known after apply)
#       + sku                     = (known after apply)
#       + zones                   = (known after apply)
#
#       + timeouts {
#           + read = (known after apply)
#         }
#     }
#
#   # azurerm_network_interface.lsml_ni will be created
#   + resource "azurerm_network_interface" "lsml_ni" {
#       + applied_dns_servers           = (known after apply)
#       + dns_servers                   = (known after apply)
#       + enable_accelerated_networking = false
#       + enable_ip_forwarding          = false
#       + id                            = (known after apply)
#       + internal_dns_name_label       = (known after apply)
#       + internal_domain_name_suffix   = (known after apply)
#       + location                      = "westus"
#       + mac_address                   = (known after apply)
#       + name                          = "lsml-nic"
#       + private_ip_address            = (known after apply)
#       + private_ip_addresses          = (known after apply)
#       + resource_group_name           = "lsml-resource-group"
#       + virtual_machine_id            = (known after apply)
#
#       + ip_configuration {
#           + name                          = "internal"
#           + primary                       = (known after apply)
#           + private_ip_address            = (known after apply)
#           + private_ip_address_allocation = "dynamic"
#           + private_ip_address_version    = "IPv4"
#           + public_ip_address_id          = (known after apply)
#           + subnet_id                     = (known after apply)
#         }
#     }
#
#   # azurerm_public_ip.lsml_pub_ip will be created
#   + resource "azurerm_public_ip" "lsml_pub_ip" {
#       + allocation_method       = "Dynamic"
#       + domain_name_label       = "alexlsmlmachine"
#       + fqdn                    = (known after apply)
#       + id                      = (known after apply)
#       + idle_timeout_in_minutes = 30
#       + ip_address              = (known after apply)
#       + ip_version              = "IPv4"
#       + location                = "westus"
#       + name                    = "lsml-public-ip"
#       + resource_group_name     = "lsml-resource-group"
#       + sku                     = "Basic"
#     }
#
#   # azurerm_subnet.lsml_subnet will be created
#   + resource "azurerm_subnet" "lsml_subnet" {
#       + address_prefix                                 = (known after apply)
#       + address_prefixes                               = [
#           + "10.0.2.0/24",
#         ]
#       + enforce_private_link_endpoint_network_policies = false
#       + enforce_private_link_service_network_policies  = false
#       + id                                             = (known after apply)
#       + name                                           = "internal"
#       + resource_group_name                            = "lsml-resource-group"
#       + virtual_network_name                           = "lsml-vitrual-network"
#     }
#
#   # azurerm_virtual_machine.lsml_vm will be created
#   + resource "azurerm_virtual_machine" "lsml_vm" {
#       + availability_set_id              = (known after apply)
#       + delete_data_disks_on_termination = false
#       + delete_os_disk_on_termination    = true
#       + id                               = (known after apply)
#       + license_type                     = (known after apply)
#       + location                         = "westus"
#       + name                             = "lsml-machine"
#       + network_interface_ids            = (known after apply)
#       + resource_group_name              = "lsml-resource-group"
#       + vm_size                          = "Standard_F2"
#
#       + identity {
#           + identity_ids = (known after apply)
#           + principal_id = (known after apply)
#           + type         = (known after apply)
#         }
#
#       + os_profile {
#           + admin_password = (sensitive value)
#           + admin_username = "azureuser"
#           + computer_name  = "hostname"
#           + custom_data    = (known after apply)
#         }
#
#       + os_profile_linux_config {
#           + disable_password_authentication = false
#
#           + ssh_keys {
#               + key_data = <<-EOT
#                     ssh-rsa ... kosmos@neatsy.ai
#                 EOT
#               + path     = "/home/azureuser/.ssh/authorized_keys"
#             }
#         }
#
#       + storage_data_disk {
#           + caching                   = (known after apply)
#           + create_option             = (known after apply)
#           + disk_size_gb              = (known after apply)
#           + lun                       = (known after apply)
#           + managed_disk_id           = (known after apply)
#           + managed_disk_type         = (known after apply)
#           + name                      = (known after apply)
#           + vhd_uri                   = (known after apply)
#           + write_accelerator_enabled = (known after apply)
#         }
#
#       + storage_image_reference {
#           + offer     = "UbuntuServer"
#           + publisher = "Canonical"
#           + sku       = "16.04-LTS"
#           + version   = "latest"
#         }
#
#       + storage_os_disk {
#           + caching                   = "ReadWrite"
#           + create_option             = "FromImage"
#           + disk_size_gb              = 200
#           + managed_disk_id           = (known after apply)
#           + managed_disk_type         = "Standard_LRS"
#           + name                      = "main-disk"
#           + os_type                   = (known after apply)
#           + write_accelerator_enabled = false
#         }
#     }
#
# Plan: 4 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   + private_ip    = (known after apply)
#   + public_domain = "alexlsmlmachine.westus.cloudapp.azure.com"
#   + public_ip     = (known after apply)
#
#
# Warning: Version constraints inside provider configuration blocks are deprecated
#
#   on common.tf line 6, in provider "azurerm":
#    6:   version = "=2.40.0"
#
# Terraform 0.13 and earlier allowed provider version constraints inside the
# provider configuration block, but that is now deprecated and will be removed
# in a future version of Terraform. To silence this warning, move the provider
# version constraint into the required_providers block.
#
# Do you want to perform these actions?
#   Terraform will perform the actions described above.
#   Only 'yes' will be accepted to approve.
#
#   Enter a value:
# azurerm_subnet.lsml_subnet: Creating...
# azurerm_public_ip.lsml_pub_ip: Creating...
# azurerm_subnet.lsml_subnet: Creation complete after 8s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network/subnets/internal]
# azurerm_public_ip.lsml_pub_ip: Still creating... [10s elapsed]
# azurerm_public_ip.lsml_pub_ip: Creation complete after 13s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip]
# azurerm_network_interface.lsml_ni: Creating...
# azurerm_network_interface.lsml_ni: Creation complete after 10s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/networkInterfaces/lsml-nic]
# azurerm_virtual_machine.lsml_vm: Creating...
# azurerm_virtual_machine.lsml_vm: Still creating... [10s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... [20s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... [30s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... [40s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... [50s elapsed]
# azurerm_virtual_machine.lsml_vm: Creation complete after 1m0s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Compute/virtualMachines/lsml-machine]
# data.azurerm_public_ip.lsml_public_ip: Reading...
# data.azurerm_public_ip.lsml_public_ip: Read complete after 0s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip]
#
# Apply complete! Resources: 4 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# private_ip = "10.0.2.4"
# public_domain = "alexlsmlmachine.westus.cloudapp.azure.com"
# public_ip = "13.91.45.230"

# %% [markdown]
# Все должно было создаться - смотрим в консоли в браузере!
#
# Параметры, которые мы специально сохранили, можно посмотреть с помощью `terraform output`

# %%
! terraform plan
# Out:
# azurerm_resource_group.lsml_rg: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group]
# azurerm_virtual_network.lsml_vn: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network]
# azurerm_public_ip.lsml_pub_ip: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip]
# azurerm_subnet.lsml_subnet: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network/subnets/internal]
# azurerm_network_interface.lsml_ni: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/networkInterfaces/lsml-nic]
# azurerm_virtual_machine.lsml_vm: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Compute/virtualMachines/lsml-machine]
#
# No changes. Infrastructure is up-to-date.
#
# This means that Terraform did not detect any differences between your
# configuration and real physical resources that exist. As a result, no
# actions need to be performed.
#
# Warning: Version constraints inside provider configuration blocks are deprecated
#
#   on common.tf line 6, in provider "azurerm":
#    6:   version = "=2.40.0"
#
# Terraform 0.13 and earlier allowed provider version constraints inside the
# provider configuration block, but that is now deprecated and will be removed
# in a future version of Terraform. To silence this warning, move the provider
# version constraint into the required_providers block.

# %%
! terraform output
# Out:
# private_ip = "10.0.2.4"
# public_domain = "alexlsmlmachine.westus.cloudapp.azure.com"
# public_ip = "13.91.45.230"

# %%
! terraform output -raw public_ip
# Out:
# 13.91.45.230

# %% [markdown]
# Можно попробовать подключиться к машине по ее публичному адресу, как мы это уже делали выше
# ```bash
# ssh azureuser@40.118.191.81
# ```
#
# Или
#
# ```bash
# ssh azureuser@alexlsmlmachine.westus.cloudapp.azure.com
# ```

# %% [markdown]
# ### Terraform provisioners
#
# Машина готова к использованию, однако на ней все еще нет нужных библиотек. Чтобы руками не устанавливать все необходимое каждый раз, можно воспользоваться провизионерами.
#
# После старта машины, terraform запустил все провизионеры по порядку. Каждый провизионер может запустить произвольные скрипты на машинах.
#
# Добавим провизионеры для установки анаконды после создания машины.

# %%
# Провизионеры запускаются только один раз при создании ресурса. Для старых ресурсов они не работают
# Поэтому удалим все созданное. Это можно сделать одной командой terraform destroy

! echo "yes" | terraform destroy
# Out:
# An execution plan has been generated and is shown below.
# Resource actions are indicated with the following symbols:
#   - destroy
#
# Terraform will perform the following actions:
#
#   # azurerm_network_interface.lsml_ni will be destroyed
#   - resource "azurerm_network_interface" "lsml_ni" {
#       - applied_dns_servers           = [] -> null
#       - dns_servers                   = [] -> null
#       - enable_accelerated_networking = false -> null
#       - enable_ip_forwarding          = false -> null
#       - id                            = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/networkInterfaces/lsml-nic" -> null
#       - internal_domain_name_suffix   = "c3li4fbr0dqudeoah3eliwpbhc.dx.internal.cloudapp.net" -> null
#       - location                      = "westus" -> null
#       - name                          = "lsml-nic" -> null
#       - private_ip_address            = "10.0.2.4" -> null
#       - private_ip_addresses          = [
#           - "10.0.2.4",
#         ] -> null
#       - resource_group_name           = "lsml-resource-group" -> null
#
#       - ip_configuration {
#           - name                          = "internal" -> null
#           - primary                       = true -> null
#           - private_ip_address            = "10.0.2.4" -> null
#           - private_ip_address_allocation = "Dynamic" -> null
#           - private_ip_address_version    = "IPv4" -> null
#           - public_ip_address_id          = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip" -> null
#           - subnet_id                     = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network/subnets/internal" -> null
#         }
#     }
#
#   # azurerm_public_ip.lsml_pub_ip will be destroyed
#   - resource "azurerm_public_ip" "lsml_pub_ip" {
#       - allocation_method       = "Dynamic" -> null
#       - domain_name_label       = "alexlsmlmachine" -> null
#       - fqdn                    = "alexlsmlmachine.westus.cloudapp.azure.com" -> null
#       - id                      = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip" -> null
#       - idle_timeout_in_minutes = 30 -> null
#       - ip_version              = "IPv4" -> null
#       - location                = "westus" -> null
#       - name                    = "lsml-public-ip" -> null
#       - resource_group_name     = "lsml-resource-group" -> null
#       - sku                     = "Basic" -> null
#     }
#
#   # azurerm_resource_group.lsml_rg will be destroyed
#   - resource "azurerm_resource_group" "lsml_rg" {
#       - id       = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group" -> null
#       - location = "westus" -> null
#       - name     = "lsml-resource-group" -> null
#     }
#
#   # azurerm_role_assignment.example will be destroyed
#   - resource "azurerm_role_assignment" "example" {
#       - id                   = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/providers/Microsoft.Authorization/roleAssignments/ccb6e779-4e81-4fc6-188a-87c18958c946" -> null
#       - name                 = "ccb6e779-4e81-4fc6-188a-87c18958c946" -> null
#       - principal_id         = "e316087f-f661-4ce2-afd7-2cac4a826d1f" -> null
#       - principal_type       = "User" -> null
#       - role_definition_id   = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/providers/Microsoft.Authorization/roleDefinitions/ba92f5b4-2d11-453d-a403-e96b0029c9fe" -> null
#       - role_definition_name = "Storage Blob Data Contributor" -> null
#       - scope                = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8" -> null
#     }
#
#   # azurerm_storage_account.lsml_sa will be destroyed
#   - resource "azurerm_storage_account" "lsml_sa" {
#       - access_tier                    = "Hot" -> null
#       - account_kind                   = "StorageV2" -> null
#       - account_replication_type       = "LRS" -> null
#       - account_tier                   = "Standard" -> null
#       - allow_blob_public_access       = true -> null
#       - enable_https_traffic_only      = true -> null
#       - id                             = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Storage/storageAccounts/lsmlstorage" -> null
#       - is_hns_enabled                 = false -> null
#       - location                       = "westus" -> null
#       - min_tls_version                = "TLS1_0" -> null
#       - name                           = "lsmlstorage" -> null
#       - primary_access_key             = (sensitive value)
#       - primary_blob_connection_string = (sensitive value)
#       - primary_blob_endpoint          = "https://lsmlstorage.blob.core.windows.net/" -> null
#       - primary_blob_host              = "lsmlstorage.blob.core.windows.net" -> null
#       - primary_connection_string      = (sensitive value)
#       - primary_dfs_endpoint           = "https://lsmlstorage.dfs.core.windows.net/" -> null
#       - primary_dfs_host               = "lsmlstorage.dfs.core.windows.net" -> null
#       - primary_file_endpoint          = "https://lsmlstorage.file.core.windows.net/" -> null
#       - primary_file_host              = "lsmlstorage.file.core.windows.net" -> null
#       - primary_location               = "westus" -> null
#       - primary_queue_endpoint         = "https://lsmlstorage.queue.core.windows.net/" -> null
#       - primary_queue_host             = "lsmlstorage.queue.core.windows.net" -> null
#       - primary_table_endpoint         = "https://lsmlstorage.table.core.windows.net/" -> null
#       - primary_table_host             = "lsmlstorage.table.core.windows.net" -> null
#       - primary_web_endpoint           = "https://lsmlstorage.z22.web.core.windows.net/" -> null
#       - primary_web_host               = "lsmlstorage.z22.web.core.windows.net" -> null
#       - resource_group_name            = "lsml-resource-group" -> null
#       - secondary_access_key           = (sensitive value)
#       - secondary_connection_string    = (sensitive value)
#
#       - network_rules {
#           - bypass                     = [
#               - "AzureServices",
#             ] -> null
#           - default_action             = "Allow" -> null
#           - ip_rules                   = [] -> null
#           - virtual_network_subnet_ids = [] -> null
#         }
#
#       - queue_properties {
#
#           - hour_metrics {
#               - enabled               = true -> null
#               - include_apis          = true -> null
#               - retention_policy_days = 7 -> null
#               - version               = "1.0" -> null
#             }
#
#           - logging {
#               - delete                = false -> null
#               - read                  = false -> null
#               - retention_policy_days = 0 -> null
#               - version               = "1.0" -> null
#               - write                 = false -> null
#             }
#
#           - minute_metrics {
#               - enabled               = false -> null
#               - include_apis          = false -> null
#               - retention_policy_days = 0 -> null
#               - version               = "1.0" -> null
#             }
#         }
#     }
#
#   # azurerm_storage_container.lsml_sc will be destroyed
#   - resource "azurerm_storage_container" "lsml_sc" {
#       - container_access_type   = "blob" -> null
#       - has_immutability_policy = false -> null
#       - has_legal_hold          = false -> null
#       - id                      = "https://lsmlstorage.blob.core.windows.net/content" -> null
#       - metadata                = {} -> null
#       - name                    = "content" -> null
#       - resource_manager_id     = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Storage/storageAccounts/lsmlstorage/blobServices/default/containers/content" -> null
#       - storage_account_name    = "lsmlstorage" -> null
#     }
#
#   # azurerm_subnet.lsml_subnet will be destroyed
#   - resource "azurerm_subnet" "lsml_subnet" {
#       - address_prefix                                 = "10.0.2.0/24" -> null
#       - address_prefixes                               = [
#           - "10.0.2.0/24",
#         ] -> null
#       - enforce_private_link_endpoint_network_policies = false -> null
#       - enforce_private_link_service_network_policies  = false -> null
#       - id                                             = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network/subnets/internal" -> null
#       - name                                           = "internal" -> null
#       - resource_group_name                            = "lsml-resource-group" -> null
#       - virtual_network_name                           = "lsml-vitrual-network" -> null
#     }
#
#   # azurerm_virtual_machine.lsml_vm will be destroyed
#   - resource "azurerm_virtual_machine" "lsml_vm" {
#       - delete_data_disks_on_termination = false -> null
#       - delete_os_disk_on_termination    = true -> null
#       - id                               = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Compute/virtualMachines/lsml-machine" -> null
#       - location                         = "westus" -> null
#       - name                             = "lsml-machine" -> null
#       - network_interface_ids            = [
#           - "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/networkInterfaces/lsml-nic",
#         ] -> null
#       - resource_group_name              = "lsml-resource-group" -> null
#       - vm_size                          = "Standard_F2" -> null
#
#       - os_profile {
#           - admin_username = "azureuser" -> null
#           - computer_name  = "hostname" -> null
#         }
#
#       - os_profile_linux_config {
#           - disable_password_authentication = false -> null
#
#           - ssh_keys {
#               - key_data = <<-EOT
#                     ssh-rsa ... kosmos@neatsy.ai
#                 EOT -> null
#               - path     = "/home/azureuser/.ssh/authorized_keys" -> null
#             }
#         }
#
#       - storage_image_reference {
#           - offer     = "UbuntuServer" -> null
#           - publisher = "Canonical" -> null
#           - sku       = "16.04-LTS" -> null
#           - version   = "latest" -> null
#         }
#
#       - storage_os_disk {
#           - caching                   = "ReadWrite" -> null
#           - create_option             = "FromImage" -> null
#           - disk_size_gb              = 200 -> null
#           - managed_disk_id           = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Compute/disks/main-disk" -> null
#           - managed_disk_type         = "Standard_LRS" -> null
#           - name                      = "main-disk" -> null
#           - os_type                   = "Linux" -> null
#           - write_accelerator_enabled = false -> null
#         }
#     }
#
#   # azurerm_virtual_network.lsml_vn will be destroyed
#   - resource "azurerm_virtual_network" "lsml_vn" {
#       - address_space         = [
#           - "10.0.0.0/16",
#         ] -> null
#       - guid                  = "148f5617-d031-41e1-91c0-3f48b459e13a" -> null
#       - id                    = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network" -> null
#       - location              = "westus" -> null
#       - name                  = "lsml-vitrual-network" -> null
#       - resource_group_name   = "lsml-resource-group" -> null
#       - subnet                = [] -> null
#       - vm_protection_enabled = false -> null
#     }
#
# Plan: 0 to add, 0 to change, 9 to destroy.
#
# Changes to Outputs:
#   - private_ip    = "10.0.2.4" -> null
#   - public_domain = "alexlsmlmachine.westus.cloudapp.azure.com" -> null
#   - public_ip     = "40.118.191.81" -> null
#
#
# Warning: Version constraints inside provider configuration blocks are deprecated
#
#   on common.tf line 6, in provider "azurerm":
#    6:   version = "=2.40.0"
#
# Terraform 0.13 and earlier allowed provider version constraints inside the
# provider configuration block, but that is now deprecated and will be removed
# in a future version of Terraform. To silence this warning, move the provider
# version constraint into the required_providers block.
#
# Do you really want to destroy all resources?
#   Terraform will destroy all your managed infrastructure, as shown above.
#   There is no undo. Only 'yes' will be accepted to confirm.
#
#   Enter a value:
# azurerm_storage_container.lsml_sc: Destroying... [id=https://lsmlstorage.blob.core.windows.net/content]
# azurerm_role_assignment.example: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/providers/Microsoft.Authorization/roleAssignments/ccb6e779-4e81-4fc6-188a-87c18958c946]
# azurerm_virtual_machine.lsml_vm: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Compute/virtualMachines/lsml-machine]
# azurerm_role_assignment.example: Destruction complete after 3s
# azurerm_storage_container.lsml_sc: Destruction complete after 3s
# azurerm_storage_account.lsml_sa: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Storage/storageAccounts/lsmlstorage]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 10s elapsed]
# azurerm_storage_account.lsml_sa: Destruction complete after 10s
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 20s elapsed]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 30s elapsed]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 40s elapsed]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 50s elapsed]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 1m0s elapsed]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 1m10s elapsed]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 1m20s elapsed]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 1m30s elapsed]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 1m40s elapsed]
# azurerm_virtual_machine.lsml_vm: Destruction complete after 1m47s
# azurerm_network_interface.lsml_ni: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/networkInterfaces/lsml-nic]
# azurerm_network_interface.lsml_ni: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...oft.Network/networkInterfaces/lsml-nic, 10s elapsed]
# azurerm_network_interface.lsml_ni: Destruction complete after 13s
# azurerm_subnet.lsml_subnet: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network/subnets/internal]
# azurerm_public_ip.lsml_pub_ip: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip]
# azurerm_subnet.lsml_subnet: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-.../lsml-vitrual-network/subnets/internal, 10s elapsed]
# azurerm_public_ip.lsml_pub_ip: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...twork/publicIPAddresses/lsml-public-ip, 10s elapsed]
# azurerm_subnet.lsml_subnet: Destruction complete after 12s
# azurerm_virtual_network.lsml_vn: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network]
# azurerm_public_ip.lsml_pub_ip: Destruction complete after 13s
# azurerm_virtual_network.lsml_vn: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...k/virtualNetworks/lsml-vitrual-network, 10s elapsed]
# azurerm_virtual_network.lsml_vn: Destruction complete after 12s
# azurerm_resource_group.lsml_rg: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group]
# azurerm_resource_group.lsml_rg: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...ba8/resourceGroups/lsml-resource-group, 10s elapsed]
# azurerm_resource_group.lsml_rg: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...ba8/resourceGroups/lsml-resource-group, 20s elapsed]
# azurerm_resource_group.lsml_rg: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...ba8/resourceGroups/lsml-resource-group, 30s elapsed]
# azurerm_resource_group.lsml_rg: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...ba8/resourceGroups/lsml-resource-group, 40s elapsed]
# azurerm_resource_group.lsml_rg: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...ba8/resourceGroups/lsml-resource-group, 50s elapsed]
# azurerm_resource_group.lsml_rg: Destruction complete after 51s
#
# Destroy complete! Resources: 9 destroyed.

# %%
# %%writefile install-conda.sh
#
# # get link from this site - https://www.anaconda.com/distribution/
#
# wget https://repo.anaconda.com/archive/Anaconda3-2020.11-Linux-x86_64.sh -O install-conda.sh
# chmod +x install-conda.sh
# ./install-conda.sh -b -p $HOME/anaconda3
#
# # add conda to PATH
#
# eval "$(/home/azureuser/anaconda3/bin/conda shell.bash hook)"
# conda init
# Out:
# Overwriting install-conda.sh

# %%
# %%writefile vm.tf
# # Здесь описываем ресурсы, необходимые для работы машины
#
# # Публичный адрес машины
# resource "azurerm_public_ip" "lsml_pub_ip" {
#   location = azurerm_resource_group.lsml_rg.location
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#
#   name = "lsml-public-ip"
#
#   allocation_method = "Dynamic"
#   # Выдаем динамический ip
#   idle_timeout_in_minutes = 30
#   domain_name_label = "alexlsmlmachine"
#   # Для удобства можно использовать DNS имя
# }
#
# # Сетевой интерфейс для нашей машины
# resource "azurerm_network_interface" "lsml_ni" {
#   location = azurerm_resource_group.lsml_rg.location
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#
#   name = "lsml-nic"
#
#   ip_configuration {
#     name = "internal"
#     private_ip_address_allocation = "Dynamic"
#     subnet_id = azurerm_subnet.lsml_subnet.id
#     public_ip_address_id = azurerm_public_ip.lsml_pub_ip.id
#   }
# }
#
# # Сама виртуальная машина
# resource "azurerm_virtual_machine" "lsml_vm" {
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#   location = azurerm_resource_group.lsml_rg.location
#
#   name = "lsml-machine"
#
#   vm_size = "Standard_F2"
#   # 2 CPU 4 GB
#   # Какие размеры вообще бывают - https://azure.microsoft.com/en-us/pricing/details/virtual-machines/series/
#
#   network_interface_ids = [
#     azurerm_network_interface.lsml_ni.id,
#     # Подключаем к сети
#   ]
#
#   storage_image_reference {
#     # Используем образ Ubuntu 16.04
#     publisher = "Canonical"
#     offer = "UbuntuServer"
#     sku = "16.04-LTS"
#     version = "latest"
#   }
#
#   os_profile {
#     computer_name = "hostname"
#     admin_username = "azureuser"
#     # Пользователь и его пароль
#     admin_password = "Password1234!"
#   }
#   os_profile_linux_config {
#     disable_password_authentication = false
#     ssh_keys {
#       path = "/home/azureuser/.ssh/authorized_keys"
#       key_data = file("~/id_rsa.pub")
#       # Можем указать наш ключ, как ключ для авторизации на машине
#     }
#   }
#
#   delete_os_disk_on_termination = true
#   storage_os_disk {
#     name = "main-disk"
#     caching = "ReadWrite"
#     create_option = "FromImage"
#     managed_disk_type = "Standard_LRS"
#     disk_size_gb = "200"
#     # Указываем какой использовать основной жесткий диск и его размер
#   }
#
#   provisioner "remote-exec" { # Запускаем удаленно
#     script = "install-conda.sh" # Указываем, какой скрипт запустить
#
#     connection {
#       # Указываем, как подключиться к машине. Будем использовать ssh с паролем и доменным именем
#       type = "ssh"
#       user = "azureuser"
#       password = "Password1234!"
#       host = "${azurerm_public_ip.lsml_pub_ip.domain_name_label}.${azurerm_resource_group.lsml_rg.location}.cloudapp.azure.com"
#     }
#   }
# }
#
# # Созраним несколько важный значений в output. Их можно будет потом использовать для наших целей
#
# data "azurerm_public_ip" "lsml_public_ip" {
#   name = azurerm_public_ip.lsml_pub_ip.name
#   resource_group_name = azurerm_virtual_machine.lsml_vm.resource_group_name
# }
#
# output "public_domain" {
#   # Домен нашего сервера
#   value = "${azurerm_public_ip.lsml_pub_ip.domain_name_label}.${azurerm_resource_group.lsml_rg.location}.cloudapp.azure.com"
# }
#
# output "public_ip" {
#   # Публичный ip нашего сервера
#   value = data.azurerm_public_ip.lsml_public_ip.ip_address
# }
#
# output "private_ip" {
#   # Приватный ip нашего сервера
#   value = azurerm_network_interface.lsml_ni.private_ip_address
# }
# Out:
# Overwriting vm.tf

# %%
! echo "yes" | terraform apply
# Out:
# An execution plan has been generated and is shown below.
# Resource actions are indicated with the following symbols:
#   + create
#  <= read (data resources)
#
# Terraform will perform the following actions:
#
#   # data.azurerm_public_ip.lsml_public_ip will be read during apply
#   # (config refers to values not yet known)
#  <= data "azurerm_public_ip" "lsml_public_ip"  {
#       + allocation_method       = (known after apply)
#       + domain_name_label       = (known after apply)
#       + fqdn                    = (known after apply)
#       + id                      = (known after apply)
#       + idle_timeout_in_minutes = (known after apply)
#       + ip_address              = (known after apply)
#       + ip_version              = (known after apply)
#       + location                = (known after apply)
#       + name                    = "lsml-public-ip"
#       + resource_group_name     = "lsml-resource-group"
#       + reverse_fqdn            = (known after apply)
#       + sku                     = (known after apply)
#       + zones                   = (known after apply)
#
#       + timeouts {
#           + read = (known after apply)
#         }
#     }
#
#   # azurerm_network_interface.lsml_ni will be created
#   + resource "azurerm_network_interface" "lsml_ni" {
#       + applied_dns_servers           = (known after apply)
#       + dns_servers                   = (known after apply)
#       + enable_accelerated_networking = false
#       + enable_ip_forwarding          = false
#       + id                            = (known after apply)
#       + internal_dns_name_label       = (known after apply)
#       + internal_domain_name_suffix   = (known after apply)
#       + location                      = "westus"
#       + mac_address                   = (known after apply)
#       + name                          = "lsml-nic"
#       + private_ip_address            = (known after apply)
#       + private_ip_addresses          = (known after apply)
#       + resource_group_name           = "lsml-resource-group"
#       + virtual_machine_id            = (known after apply)
#
#       + ip_configuration {
#           + name                          = "internal"
#           + primary                       = (known after apply)
#           + private_ip_address            = (known after apply)
#           + private_ip_address_allocation = "dynamic"
#           + private_ip_address_version    = "IPv4"
#           + public_ip_address_id          = (known after apply)
#           + subnet_id                     = (known after apply)
#         }
#     }
#
#   # azurerm_public_ip.lsml_pub_ip will be created
#   + resource "azurerm_public_ip" "lsml_pub_ip" {
#       + allocation_method       = "Dynamic"
#       + domain_name_label       = "alexlsmlmachine"
#       + fqdn                    = (known after apply)
#       + id                      = (known after apply)
#       + idle_timeout_in_minutes = 30
#       + ip_address              = (known after apply)
#       + ip_version              = "IPv4"
#       + location                = "westus"
#       + name                    = "lsml-public-ip"
#       + resource_group_name     = "lsml-resource-group"
#       + sku                     = "Basic"
#     }
#
#   # azurerm_resource_group.lsml_rg will be created
#   + resource "azurerm_resource_group" "lsml_rg" {
#       + id       = (known after apply)
#       + location = "westus"
#       + name     = "lsml-resource-group"
#     }
#
#   # azurerm_subnet.lsml_subnet will be created
#   + resource "azurerm_subnet" "lsml_subnet" {
#       + address_prefix                                 = (known after apply)
#       + address_prefixes                               = [
#           + "10.0.2.0/24",
#         ]
#       + enforce_private_link_endpoint_network_policies = false
#       + enforce_private_link_service_network_policies  = false
#       + id                                             = (known after apply)
#       + name                                           = "internal"
#       + resource_group_name                            = "lsml-resource-group"
#       + virtual_network_name                           = "lsml-vitrual-network"
#     }
#
#   # azurerm_virtual_machine.lsml_vm will be created
#   + resource "azurerm_virtual_machine" "lsml_vm" {
#       + availability_set_id              = (known after apply)
#       + delete_data_disks_on_termination = false
#       + delete_os_disk_on_termination    = true
#       + id                               = (known after apply)
#       + license_type                     = (known after apply)
#       + location                         = "westus"
#       + name                             = "lsml-machine"
#       + network_interface_ids            = (known after apply)
#       + resource_group_name              = "lsml-resource-group"
#       + vm_size                          = "Standard_F2"
#
#       + identity {
#           + identity_ids = (known after apply)
#           + principal_id = (known after apply)
#           + type         = (known after apply)
#         }
#
#       + os_profile {
#           + admin_password = (sensitive value)
#           + admin_username = "azureuser"
#           + computer_name  = "hostname"
#           + custom_data    = (known after apply)
#         }
#
#       + os_profile_linux_config {
#           + disable_password_authentication = false
#
#           + ssh_keys {
#               + key_data = <<-EOT
#                     ssh-rsa ... kosmos@neatsy.ai
#                 EOT
#               + path     = "/home/azureuser/.ssh/authorized_keys"
#             }
#         }
#
#       + storage_data_disk {
#           + caching                   = (known after apply)
#           + create_option             = (known after apply)
#           + disk_size_gb              = (known after apply)
#           + lun                       = (known after apply)
#           + managed_disk_id           = (known after apply)
#           + managed_disk_type         = (known after apply)
#           + name                      = (known after apply)
#           + vhd_uri                   = (known after apply)
#           + write_accelerator_enabled = (known after apply)
#         }
#
#       + storage_image_reference {
#           + offer     = "UbuntuServer"
#           + publisher = "Canonical"
#           + sku       = "16.04-LTS"
#           + version   = "latest"
#         }
#
#       + storage_os_disk {
#           + caching                   = "ReadWrite"
#           + create_option             = "FromImage"
#           + disk_size_gb              = 200
#           + managed_disk_id           = (known after apply)
#           + managed_disk_type         = "Standard_LRS"
#           + name                      = "main-disk"
#           + os_type                   = (known after apply)
#           + write_accelerator_enabled = false
#         }
#     }
#
#   # azurerm_virtual_network.lsml_vn will be created
#   + resource "azurerm_virtual_network" "lsml_vn" {
#       + address_space         = [
#           + "10.0.0.0/16",
#         ]
#       + guid                  = (known after apply)
#       + id                    = (known after apply)
#       + location              = "westus"
#       + name                  = "lsml-vitrual-network"
#       + resource_group_name   = "lsml-resource-group"
#       + subnet                = (known after apply)
#       + vm_protection_enabled = false
#     }
#
# Plan: 6 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   + private_ip    = (known after apply)
#   + public_domain = "alexlsmlmachine.westus.cloudapp.azure.com"
#   + public_ip     = (known after apply)
#
#
# Warning: Version constraints inside provider configuration blocks are deprecated
#
#   on common.tf line 6, in provider "azurerm":
#    6:   version = "=2.40.0"
#
# Terraform 0.13 and earlier allowed provider version constraints inside the
# provider configuration block, but that is now deprecated and will be removed
# in a future version of Terraform. To silence this warning, move the provider
# version constraint into the required_providers block.
#
# Do you want to perform these actions?
#   Terraform will perform the actions described above.
#   Only 'yes' will be accepted to approve.
#
#   Enter a value:
# azurerm_resource_group.lsml_rg: Creating...
# azurerm_resource_group.lsml_rg: Creation complete after 3s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group]
# azurerm_virtual_network.lsml_vn: Creating...
# azurerm_public_ip.lsml_pub_ip: Creating...
# azurerm_virtual_network.lsml_vn: Still creating... [10s elapsed]
# azurerm_public_ip.lsml_pub_ip: Still creating... [10s elapsed]
# azurerm_public_ip.lsml_pub_ip: Creation complete after 12s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip]
# azurerm_virtual_network.lsml_vn: Creation complete after 12s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network]
# azurerm_subnet.lsml_subnet: Creating...
# azurerm_subnet.lsml_subnet: Creation complete after 7s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network/subnets/internal]
# azurerm_network_interface.lsml_ni: Creating...
# azurerm_network_interface.lsml_ni: Still creating... [10s elapsed]
# azurerm_network_interface.lsml_ni: Creation complete after 10s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/networkInterfaces/lsml-nic]
# azurerm_virtual_machine.lsml_vm: Creating...
# azurerm_virtual_machine.lsml_vm: Still creating... [10s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... [20s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... [30s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... [40s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... [50s elapsed]
# azurerm_virtual_machine.lsml_vm: Provisioning with 'remote-exec'...
# azurerm_virtual_machine.lsml_vm (remote-exec): Connecting to remote host via SSH...
# azurerm_virtual_machine.lsml_vm (remote-exec):   Host: alexlsmlmachine.westus.cloudapp.azure.com
# azurerm_virtual_machine.lsml_vm (remote-exec):   User: azureuser
# azurerm_virtual_machine.lsml_vm (remote-exec):   Password: true
# azurerm_virtual_machine.lsml_vm (remote-exec):   Private key: false
# azurerm_virtual_machine.lsml_vm (remote-exec):   Certificate: false
# azurerm_virtual_machine.lsml_vm (remote-exec):   SSH Agent: false
# azurerm_virtual_machine.lsml_vm (remote-exec):   Checking Host Key: false
# azurerm_virtual_machine.lsml_vm: Still creating... 0s elapsed]
# azurerm_virtual_machine.lsml_vm (remote-exec): Connected!
# azurerm_virtual_machine.lsml_vm (remote-exec): --2021-01-06 11:17:47--  https://repo.anaconda.com/archive/Anaconda3-2020.11-Linux-x86_64.sh
# azurerm_virtual_machine.lsml_vm (remote-exec): Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# azurerm_virtual_machine.lsml_vm (remote-exec): Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# azurerm_virtual_machine.lsml_vm (remote-exec): HTTP request sent, awaiting response... 200 OK
# azurerm_virtual_machine.lsml_vm (remote-exec): Length: 554535580
# azurerm_virtual_machine.lsml_vm (remote-exec):  (529M) [application/x-sh]
# azurerm_virtual_machine.lsml_vm (remote-exec): Saving to: ‘install-conda.sh’
#
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con   0%       0  --.-KB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con   8%  45.11M   225MB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con  17%  93.55M   234MB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con  26% 139.01M   232MB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con  34% 182.72M   228MB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con  43% 231.90M   232MB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con  52% 277.97M   232MB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con  61% 325.42M   232MB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con  61% 327.05M   166MB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con  70% 370.52M   170MB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con  78% 417.27M   175MB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con  87% 465.19M   180MB/s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con  94% 500.70M   117MB/s    eta 0s
# azurerm_virtual_machine.lsml_vm (remote-exec): install-con 100% 528.85M   120MB/s    in 4.4s
#
# azurerm_virtual_machine.lsml_vm (remote-exec): 2021-01-06 11:17:52 (120 MB/s) - ‘install-conda.sh’ saved [554535580/554535580]
#
# azurerm_virtual_machine.lsml_vm (remote-exec): PREFIX=/home/azureuser/anaconda3
# azurerm_virtual_machine.lsml_vm: Still creating... 10s elapsed]
# azurerm_virtual_machine.lsml_vm (remote-exec): Unpacking payload ...
# azurerm_virtual_machine.lsml_vm: Still creating... 20s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... 30s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... 40s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... 50s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... 0s elapsed]
# azurerm_virtual_machine.lsml_vm (remote-exec):   0%|           | 0/322 [00:00<?, ?it/s]
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : xlwt-1.3.0-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : xlwt-1.3.0-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : matplotlib-base-3.3.2-py38h
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pango-1.45.3-hd140c19_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pango-1.45.3-hd140c19_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pkginfo-1.6.1-py38h06a4308_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : click-7.1.2-py_0.conda:   1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ld_impl_linux-64-2.33.1-h53
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ld_impl_linux-64-2.33.1-h53
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libarchive-3.4.2-h62408e4_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libtiff-4.1.0-h2733197_1.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : bkcharts-0.2-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : blas-1.0-mkl.conda:   3%| |
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : blas-1.0-mkl.conda:   3%| |
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pycodestyle-2.6.0-py_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : xz-5.2.5-h7b6447c_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : xz-5.2.5-h7b6447c_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : _ipyw_jlab_nb_ext_conf-0.1.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libssh2-1.9.0-h1ba5d50_1.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libssh2-1.9.0-h1ba5d50_1.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : decorator-4.4.2-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : gstreamer-1.14.0-hb31296c_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : gstreamer-1.14.0-hb31296c_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : zope.interface-5.1.2-py38h7
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jupyterlab_server-1.2.0-py_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : cffi-1.14.3-py38he30daa8_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : cffi-1.14.3-py38he30daa8_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : typing_extensions-3.7.4.3-p
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libxslt-1.1.34-hc22bd24_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libxslt-1.1.34-hc22bd24_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : zope-1.0-py38_1.conda:   7%
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : prompt-toolkit-3.0.8-py_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : prompt-toolkit-3.0.8-py_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : iniconfig-1.1.1-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : setuptools-50.3.1-py38h06a4
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : setuptools-50.3.1-py38h06a4
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : lxml-4.6.1-py38hefd8a0e_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : python-3.8.5-h7579374_1.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : python-3.8.5-h7579374_1.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : prompt_toolkit-3.0.8-0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : chardet-3.0.4-py38_1003.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : openssl-1.1.1h-h7b6447c_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : dbus-1.13.18-hb2f20db_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : backports.functools_lru_cac
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jdcal-1.4.1-py_0.conda:  10
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : json5-0.9.5-py_0.conda:  10
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : json5-0.9.5-py_0.conda:  11
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : conda-package-handling-1.7.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : matplotlib-3.3.2-0.conda:
# azurerm_virtual_machine.lsml_vm: Still creating... 10s elapsed]
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mkl-service-2.3.0-py38he904
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mkl-service-2.3.0-py38he904
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : networkx-2.5-py_0.conda:  1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : xlrd-1.2.0-py_0.conda:  12%
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : intel-openmp-2020.2-254.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : intel-openmp-2020.2-254.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ripgrep-12.1.1-0.conda:  12
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libsodium-1.0.18-h7b6447c_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jupyter_console-6.2.0-py_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jupyter_console-6.2.0-py_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : wrapt-1.11.2-py38h7b6447c_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pytables-3.6.1-py38h9fd0a39
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : defusedxml-0.6.0-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : defusedxml-0.6.0-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : rope-0.18.0-py_0.conda:  14
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : python-libarchive-c-2.9-py_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : patchelf-0.12-he6710b0_0.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : patchelf-0.12-he6710b0_0.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : docutils-0.16-py38_1.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : _libgcc_mutex-0.1-main.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : numpy-base-1.19.2-py38hfa32
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : numpy-base-1.19.2-py38hfa32
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : python-language-server-0.35
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : astroid-2.4.2-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : statsmodels-0.12.0-py38h7b6
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : statsmodels-0.12.0-py38h7b6
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : flake8-3.8.4-py_0.conda:  1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libcurl-7.71.1-h20c2e04_1.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pcre-8.44-he6710b0_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : intervaltree-3.1.0-py_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : h5py-2.10.0-py38h7918eee_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : h5py-2.10.0-py38h7918eee_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : certifi-2020.6.20-pyhd3eb1b
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libedit-3.1.20191231-h14c39
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : simplegeneric-0.8.1-py38_2.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : simplegeneric-0.8.1-py38_2.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pyxdg-0.27-pyhd3eb1b0_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pep8-1.7.1-py38_0.conda:  2
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pep8-1.7.1-py38_0.conda:  2
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : patsy-0.5.1-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : bzip2-1.0.8-h7b6447c_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libllvm10-10.0.1-hbcb73fb_5
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libllvm10-10.0.1-hbcb73fb_5
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : clyent-1.2.2-py38_1.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : terminado-0.9.1-py38_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : yapf-0.30.0-py_0.conda:  22
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ipython-7.19.0-py38hb070fc8
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : notebook-6.1.4-py38_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : notebook-6.1.4-py38_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : xlsxwriter-1.3.7-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : nbconvert-6.0.7-py38_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : backports.tempfile-1.0-py_1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : singledispatch-3.4.0.3-py_1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : tifffile-2020.10.1-py38hdd0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : tifffile-2020.10.1-py38hdd0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : et_xmlfile-1.0.1-py_1001.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : requests-2.24.0-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : importlib-metadata-2.0.0-py
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : conda-4.9.2-py38h06a4308_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : conda-4.9.2-py38h06a4308_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pyzmq-19.0.2-py38he6710b0_1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pillow-8.0.1-py38he98fc37_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : alabaster-0.7.12-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : alabaster-0.7.12-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mkl_random-1.1.1-py38h0573a
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : icu-58.2-he6710b0_3.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : icu-58.2-he6710b0_3.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : backports.weakref-1.0.post1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : graphite2-1.3.14-h23475e2_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : gmpy2-2.0.8-py38hd5f6e3b_3.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libstdcxx-ng-9.1.0-hdf63c60
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libstdcxx-ng-9.1.0-hdf63c60
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libpng-1.6.37-hbc83047_0.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : webencodings-0.5.1-py38_1.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jedi-0.17.1-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jedi-0.17.1-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : tqdm-4.50.2-py_0.conda:  29
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : get_terminal_size-1.0.0-haa
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : msgpack-python-1.0.0-py38hf
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : colorama-0.4.4-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : colorama-0.4.4-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sphinxcontrib-jsmath-1.0.1-
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mpfr-4.0.2-hb69a4c5_1.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mpfr-4.0.2-hb69a4c5_1.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : diff-match-patch-20200713-p
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : brotlipy-0.7.0-py38h7b6447c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : brotlipy-0.7.0-py38h7b6447c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : harfbuzz-2.4.0-hca77d97_1.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : dask-2.30.0-py_0.conda:  32
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pyyaml-5.3.1-py38h7b6447c_1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : bleach-3.2.1-py_0.conda:  3
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : bleach-3.2.1-py_0.conda:  3
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sqlite-3.33.0-h62c20be_0.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : numexpr-2.7.1-py38h423224d_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : bokeh-2.2.3-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : bokeh-2.2.3-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : toml-0.10.1-py_0.conda:  34
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : cython-0.29.21-py38he6710b0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mock-4.0.2-py_0.conda:  34%
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mock-4.0.2-py_0.conda:  35%
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : wurlitzer-2.0.1-py38_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : asn1crypto-1.4.0-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : xmltodict-0.12.0-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pexpect-4.8.0-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pexpect-4.8.0-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : conda-build-3.20.5-py38_1.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libtool-2.4.6-h7b6447c_1005
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : krb5-1.18.2-h173b8e3_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : krb5-1.18.2-h173b8e3_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : anaconda-client-1.7.2-py38_
# azurerm_virtual_machine.lsml_vm: Still creating... 20s elapsed]
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : astropy-4.0.2-py38h7b6447c_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : astropy-4.0.2-py38h7b6447c_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : bitarray-1.6.1-py38h27cfd23
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : qtawesome-1.0.1-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : entrypoints-0.3-py38_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : conda-env-2.6.0-1.conda:  3
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ptyprocess-0.6.0-py38_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ptyprocess-0.6.0-py38_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sortedcontainers-2.2.2-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : backcall-0.2.0-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : backports.shutil_get_termin
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : backports.shutil_get_termin
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : tornado-6.0.4-py38h7b6447c_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pytz-2020.1-py_0.conda:  40
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : joblib-0.17.0-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : joblib-0.17.0-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mistune-0.8.4-py38h7b6447c_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : zope.event-4.5.0-py38_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : gevent-20.9.0-py38h7b6447c_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : gevent-20.9.0-py38h7b6447c_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : zlib-1.2.11-h7b6447c_3.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pluggy-0.13.1-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : wheel-0.35.1-py_0.conda:  4
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : wheel-0.35.1-py_0.conda:  4
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : keyring-21.4.0-py38_1.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : qtconsole-4.7.7-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libspatialindex-1.9.3-he671
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libspatialindex-1.9.3-he671
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pycurl-7.43.0.6-py38h1ba5d5
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jupyter_client-6.1.7-py_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : rtree-0.9.4-py38_1.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : rtree-0.9.4-py38_1.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pyrsistent-0.17.3-py38h7b64
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libxcb-1.14-h7b6447c_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pathtools-0.1.2-py_1.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pathtools-0.1.2-py_1.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : nbformat-5.0.8-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : unixodbc-2.3.9-h7b6447c_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sphinxcontrib-websupport-1.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sphinxcontrib-websupport-1.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pathlib2-2.3.5-py38_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : zipp-3.4.0-pyhd3eb1b0_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : py-lief-0.10.1-py38h403a769
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : py-lief-0.10.1-py38h403a769
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : argon2-cffi-20.1.0-py38h7b6
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : boto-2.49.0-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : atomicwrites-1.4.0-py_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : atomicwrites-1.4.0-py_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pydocstyle-5.1.1-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : send2trash-1.5.0-py38_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : widgetsnbextension-3.5.1-py
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : widgetsnbextension-3.5.1-py
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ply-3.11-py38_0.conda:  49%
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : cycler-0.10.0-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : nltk-3.5-py_0.conda:  50%|▌
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : nltk-3.5-py_0.conda:  50%|▌
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : imagesize-1.2.0-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pygments-2.7.2-pyhd3eb1b0_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pygments-2.7.2-pyhd3eb1b0_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : spyder-4.1.5-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : importlib_metadata-2.0.0-1.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : importlib_metadata-2.0.0-1.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : glib-2.66.1-h92f7085_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pytest-6.1.1-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pytest-6.1.1-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : olefile-0.46-py_0.conda:  5
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : cytoolz-0.11.0-py38h7b6447c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : cytoolz-0.11.0-py38h7b6447c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : itsdangerous-1.1.0-py_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : argh-0.26.2-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : argh-0.26.2-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : more-itertools-8.6.0-pyhd3e
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : backports-1.0-py_2.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : werkzeug-1.0.1-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : werkzeug-1.0.1-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : six-1.15.0-py38h06a4308_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sphinxcontrib-1.0-py38_1.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pyodbc-4.0.30-py38he6710b0_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pyodbc-4.0.30-py38he6710b0_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : tbb-2020.3-hfd86e86_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : parso-0.7.0-py_0.conda:  56
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : fastcache-1.1.0-py38h7b6447
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : fastcache-1.1.0-py38h7b6447
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : nbclient-0.5.1-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pip-20.2.4-py38h06a4308_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pip-20.2.4-py38h06a4308_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sphinxcontrib-qthelp-1.0.3-
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : zict-2.0.0-py_0.conda:  57%
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : kiwisolver-1.3.0-py38h25316
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ncurses-6.2-he6710b0_1.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ncurses-6.2-he6710b0_1.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jpeg-9b-h024ee3a_2.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : openpyxl-3.0.5-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : autopep8-1.5.4-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : autopep8-1.5.4-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libuuid-1.0.3-h1bed415_2.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sqlalchemy-1.3.20-py38h7b64
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sqlalchemy-1.3.20-py38h7b64
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : numpydoc-1.1.0-pyhd3eb1b0_1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pandoc-2.11-hb0f4dca_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pandoc-2.11-hb0f4dca_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jupyter_core-4.6.3-py38_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pandocfilters-1.4.3-py38h06
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : psutil-5.7.2-py38h7b6447c_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : snowballstemmer-2.0.0-py_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : snowballstemmer-2.0.0-py_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sphinxcontrib-devhelp-1.0.2
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : isort-5.6.4-py_0.conda:  62
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : isort-5.6.4-py_0.conda:  62
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ruamel_yaml-0.15.87-py38h7b
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jbig-2.1-hdba287a_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jbig-2.1-hdba287a_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : qdarkstyle-2.8.1-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : fsspec-0.8.3-py_0.conda:  6
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : path-15.0.0-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : path-15.0.0-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pandas-1.1.3-py38he6710b0_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : async_generator-1.10-py_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : async_generator-1.10-py_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : nest-asyncio-1.4.2-pyhd3eb1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : watchdog-0.10.3-py38_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : freetype-2.10.4-h5ab3b9f_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : numba-0.51.2-py38h0573a6f_1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : numba-0.51.2-py38h0573a6f_1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mkl_fft-1.2.0-py38h23d657b_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pyflakes-2.2.0-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ca-certificates-2020.10.14-
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : py-1.9.0-py_0.conda:  66%|▋
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : py-1.9.0-py_0.conda:  67%|▋
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : scikit-learn-0.23.2-py38h05
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : prometheus_client-0.8.0-py_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : prometheus_client-0.8.0-py_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : future-0.18.2-py38_1.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : contextlib2-0.6.0.post1-py_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : contextlib2-0.6.0.post1-py_
# azurerm_virtual_machine.lsml_vm: Still creating... 30s elapsed]
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mccabe-0.6.1-py38_1.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : babel-2.8.1-pyhd3eb1b0_0.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : babel-2.8.1-pyhd3eb1b0_0.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jsonschema-3.2.0-py_2.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ipykernel-5.3.4-py38h5ca1d4
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pywavelets-1.1.1-py38h7b644
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pywavelets-1.1.1-py38h7b644
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sphinxcontrib-applehelp-1.0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libffi-3.3-he6710b0_2.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libffi-3.3-he6710b0_2.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : fontconfig-2.13.0-h9420a91_
# azurerm_virtual_machine.lsml_vm: Still creating... 40s elapsed]
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sympy-1.6.2-py38h06a4308_1.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sympy-1.6.2-py38h06a4308_1.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : cryptography-3.1.1-py38h1ba
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : cairo-1.14.12-h8948797_3.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : gmp-6.1.2-h6c8ec71_1.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pyopenssl-19.1.0-py_1.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : navigator-updater-0.2.1-py3
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : navigator-updater-0.2.1-py3
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jupyterlab_pygments-0.1.2-p
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : dask-core-2.30.0-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : anaconda-project-0.8.4-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : anaconda-project-0.8.4-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : hdf5-1.10.4-hb1b8bf9_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : llvmlite-0.34.0-py38h269e1b
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : distributed-2.30.1-py38h06a
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : distributed-2.30.1-py38h06a
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : regex-2020.10.15-py38h7b644
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sortedcollections-1.2.1-py_
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pycparser-2.20-py_2.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pycparser-2.20-py_2.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sip-4.19.13-py38he6710b0_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : secretstorage-3.1.2-py38_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jupyterlab-2.2.6-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jupyterlab-2.2.6-py_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : tblib-1.7.0-py_0.conda:  76
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sphinx-3.2.1-py_0.conda:  7
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sphinx-3.2.1-py_0.conda:  7
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : greenlet-0.4.17-py38h7b6447
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : lzo-2.10-h7b6447c_2.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : numpy-1.19.2-py38h54aff64_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : numpy-1.19.2-py38h54aff64_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : traitlets-5.0.5-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : flask-1.1.2-py_0.conda:  78
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jeepney-0.5.0-pyhd3eb1b0_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : jeepney-0.5.0-pyhd3eb1b0_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ujson-4.0.1-py38he6710b0_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : zstd-1.4.5-h9ceee32_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : scikit-image-0.17.2-py38hdf
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : scikit-image-0.17.2-py38hdf
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : zeromq-4.3.3-he6710b0_3.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : heapdict-1.0.1-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : conda-verify-3.4.2-py_1.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : locket-0.2.0-py38_1.conda:
# azurerm_virtual_machine.lsml_vm: Still creating... 50s elapsed]
# azurerm_virtual_machine.lsml_vm: Still creating... 0s elapsed]
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : locket-0.2.0-py38_1.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mkl-2020.2-256.conda:  81%|
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mkl-2020.2-256.conda:  81%|
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : readline-8.0-h7b6447c_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pysocks-1.7.1-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libgfortran-ng-7.3.0-hdf63c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : qt-5.9.7-h5867ecd_1.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : idna-2.10-py_0.conda:  82%|
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : liblief-0.10.1-he6710b0_0.c
# azurerm_virtual_machine.lsml_vm: Still creating... 10s elapsed]
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pyparsing-2.4.7-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pyparsing-2.4.7-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : lcms2-2.11-h396b838_0.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : soupsieve-2.0.1-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : soupsieve-2.0.1-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : fribidi-1.0.10-h7b6447c_0.c
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : toolz-0.11.1-py_0.conda:  8
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : imageio-2.9.0-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : imageio-2.9.0-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : ipywidgets-7.5.1-py_1.conda
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : bottleneck-1.3.2-py38heb32a
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : bottleneck-1.3.2-py38heb32a
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : blosc-1.20.1-hd408876_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : blosc-1.20.1-hd408876_0.con
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : tk-8.6.10-hbc83047_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pickleshare-0.7.5-py38_1000
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pickleshare-0.7.5-py38_1000
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : mpmath-1.1.0-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : spyder-kernels-1.9.4-py38_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libgcc-ng-9.1.0-hdf63c60_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : libgcc-ng-9.1.0-hdf63c60_0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : curl-7.71.1-hbc83047_1.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : testpath-0.4.4-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : cloudpickle-1.6.0-py_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : cloudpickle-1.6.0-py_0.cond
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : threadpoolctl-2.1.0-pyh5ca1
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pylint-2.6.0-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : pylint-2.6.0-py38_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : unicodecsv-0.14.1-py38_0.co
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : anaconda-navigator-1.10.0-p
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : anaconda-navigator-1.10.0-p
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : wcwidth-0.2.5-py_0.conda:
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sphinxcontrib-htmlhelp-1.0.
# azurerm_virtual_machine.lsml_vm (remote-exec): Extracting : sphinxcontrib-htmlhelp-1.0.
# ...
# azurerm_virtual_machine.lsml_vm (remote-exec):   sortedcontainers   pkgs/main/noarch::sortedcontainers-2.2.2-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   soupsieve          pkgs/main/noarch::soupsieve-2.0.1-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   sphinx             pkgs/main/noarch::sphinx-3.2.1-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   sphinxcontrib      pkgs/main/linux-64::sphinxcontrib-1.0-py38_1
# azurerm_virtual_machine.lsml_vm (remote-exec):   sphinxcontrib-app~ pkgs/main/noarch::sphinxcontrib-applehelp-1.0.2-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   sphinxcontrib-dev~ pkgs/main/noarch::sphinxcontrib-devhelp-1.0.2-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   sphinxcontrib-htm~ pkgs/main/noarch::sphinxcontrib-htmlhelp-1.0.3-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   sphinxcontrib-jsm~ pkgs/main/noarch::sphinxcontrib-jsmath-1.0.1-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   sphinxcontrib-qth~ pkgs/main/noarch::sphinxcontrib-qthelp-1.0.3-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   sphinxcontrib-ser~ pkgs/main/noarch::sphinxcontrib-serializinghtml-1.1.4-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   sphinxcontrib-web~ pkgs/main/noarch::sphinxcontrib-websupport-1.2.4-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   spyder             pkgs/main/linux-64::spyder-4.1.5-py38_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   spyder-kernels     pkgs/main/linux-64::spyder-kernels-1.9.4-py38_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   sqlalchemy         pkgs/main/linux-64::sqlalchemy-1.3.20-py38h7b6447c_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   sqlite             pkgs/main/linux-64::sqlite-3.33.0-h62c20be_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   statsmodels        pkgs/main/linux-64::statsmodels-0.12.0-py38h7b6447c_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   sympy              pkgs/main/linux-64::sympy-1.6.2-py38h06a4308_1
# azurerm_virtual_machine.lsml_vm (remote-exec):   tbb                pkgs/main/linux-64::tbb-2020.3-hfd86e86_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   tblib              pkgs/main/noarch::tblib-1.7.0-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   terminado          pkgs/main/linux-64::terminado-0.9.1-py38_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   testpath           pkgs/main/noarch::testpath-0.4.4-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.1.0-pyh5ca1d4c_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   tifffile           pkgs/main/linux-64::tifffile-2020.10.1-py38hdd07704_2
# azurerm_virtual_machine.lsml_vm (remote-exec):   tk                 pkgs/main/linux-64::tk-8.6.10-hbc83047_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   toml               pkgs/main/noarch::toml-0.10.1-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   toolz              pkgs/main/noarch::toolz-0.11.1-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   tornado            pkgs/main/linux-64::tornado-6.0.4-py38h7b6447c_1
# azurerm_virtual_machine.lsml_vm (remote-exec):   tqdm               pkgs/main/noarch::tqdm-4.50.2-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   traitlets          pkgs/main/noarch::traitlets-5.0.5-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   typing_extensions  pkgs/main/noarch::typing_extensions-3.7.4.3-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   ujson              pkgs/main/linux-64::ujson-4.0.1-py38he6710b0_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   unicodecsv         pkgs/main/linux-64::unicodecsv-0.14.1-py38_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   unixodbc           pkgs/main/linux-64::unixodbc-2.3.9-h7b6447c_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   urllib3            pkgs/main/noarch::urllib3-1.25.11-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   watchdog           pkgs/main/linux-64::watchdog-0.10.3-py38_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   wcwidth            pkgs/main/noarch::wcwidth-0.2.5-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   webencodings       pkgs/main/linux-64::webencodings-0.5.1-py38_1
# azurerm_virtual_machine.lsml_vm (remote-exec):   werkzeug           pkgs/main/noarch::werkzeug-1.0.1-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   wheel              pkgs/main/noarch::wheel-0.35.1-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   widgetsnbextension pkgs/main/linux-64::widgetsnbextension-3.5.1-py38_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   wrapt              pkgs/main/linux-64::wrapt-1.11.2-py38h7b6447c_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   wurlitzer          pkgs/main/linux-64::wurlitzer-2.0.1-py38_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   xlrd               pkgs/main/noarch::xlrd-1.2.0-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   xlsxwriter         pkgs/main/noarch::xlsxwriter-1.3.7-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   xlwt               pkgs/main/linux-64::xlwt-1.3.0-py38_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   xmltodict          pkgs/main/noarch::xmltodict-0.12.0-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   yapf               pkgs/main/noarch::yapf-0.30.0-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   zeromq             pkgs/main/linux-64::zeromq-4.3.3-he6710b0_3
# azurerm_virtual_machine.lsml_vm (remote-exec):   zict               pkgs/main/noarch::zict-2.0.0-py_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   zipp               pkgs/main/noarch::zipp-3.4.0-pyhd3eb1b0_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
# azurerm_virtual_machine.lsml_vm (remote-exec):   zope               pkgs/main/linux-64::zope-1.0-py38_1
# azurerm_virtual_machine.lsml_vm (remote-exec):   zope.event         pkgs/main/linux-64::zope.event-4.5.0-py38_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   zope.interface     pkgs/main/linux-64::zope.interface-5.1.2-py38h7b6447c_0
# azurerm_virtual_machine.lsml_vm (remote-exec):   zstd               pkgs/main/linux-64::zstd-1.4.5-h9ceee32_0
# azurerm_virtual_machine.lsml_vm (remote-exec): Preparing transaction: \
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)done
# azurerm_virtual_machine.lsml_vm (remote-exec): Executing transaction: -
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm: Still creating... 30s elapsed]
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm: Still creating... 40s elapsed]
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)-
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)/
# azurerm_virtual_machine.lsml_vm (remote-exec)\
# azurerm_virtual_machine.lsml_vm (remote-exec)|
# azurerm_virtual_machine.lsml_vm (remote-exec)done
# azurerm_virtual_machine.lsml_vm (remote-exec): installation finished.
# azurerm_virtual_machine.lsml_vm (remote-exec): no change     /home/azureuser/anaconda3/condabin/conda
# azurerm_virtual_machine.lsml_vm (remote-exec): no change     /home/azureuser/anaconda3/bin/conda
# azurerm_virtual_machine.lsml_vm (remote-exec): no change     /home/azureuser/anaconda3/bin/conda-env
# azurerm_virtual_machine.lsml_vm (remote-exec): no change     /home/azureuser/anaconda3/bin/activate
# azurerm_virtual_machine.lsml_vm (remote-exec): no change     /home/azureuser/anaconda3/bin/deactivate
# azurerm_virtual_machine.lsml_vm (remote-exec): no change     /home/azureuser/anaconda3/etc/profile.d/conda.sh
# azurerm_virtual_machine.lsml_vm (remote-exec): no change     /home/azureuser/anaconda3/etc/fish/conf.d/conda.fish
# azurerm_virtual_machine.lsml_vm (remote-exec): no change     /home/azureuser/anaconda3/shell/condabin/Conda.psm1
# azurerm_virtual_machine.lsml_vm (remote-exec): no change     /home/azureuser/anaconda3/shell/condabin/conda-hook.ps1
# azurerm_virtual_machine.lsml_vm (remote-exec): no change     /home/azureuser/anaconda3/lib/python3.8/site-packages/xontrib/conda.xsh
# azurerm_virtual_machine.lsml_vm (remote-exec): no change     /home/azureuser/anaconda3/etc/profile.d/conda.csh
# azurerm_virtual_machine.lsml_vm (remote-exec): modified      /home/azureuser/.bashrc
#
# azurerm_virtual_machine.lsml_vm (remote-exec): ==> For changes to take effect, close and re-open your current shell. <==
#
# azurerm_virtual_machine.lsml_vm: Creation complete after 3m50s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Compute/virtualMachines/lsml-machine]
# data.azurerm_public_ip.lsml_public_ip: Reading...
# data.azurerm_public_ip.lsml_public_ip: Read complete after 1s [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip]
#
# Apply complete! Resources: 6 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# private_ip = "10.0.2.4"
# public_domain = "alexlsmlmachine.westus.cloudapp.azure.com"
# public_ip = "104.42.71.2"

# %%
! terraform output
# Out:
# private_ip = "10.0.2.4"
# public_domain = "alexlsmlmachine.westus.cloudapp.azure.com"
# public_ip = "104.42.71.2"

# %% [markdown]
# ### Хранилище файлов
#
# Когда мы говорим про машинное обучение, самое ценный компонент - это сами данные. Однако хранить их на жестком диске машине часто бывает слишком затратно - машина стоит относительно недешево и хочется избежать того, что она простаивает без дела, при этом не терять данные.
#
# Один из подходов - это подключаемые жесткие диски, которые остаются в облаке даже после удаления машины. Однако для доступа к таким данных необходимо вновь арендовать новую машину и сам процесс управления такими дисками не слишком удобный. Поэтому мы пойдем другим путем, который окажется крайней полезными при дальшейшей работе с вычислительными кластерами.
#
# В Azure есть специальный ресурс, который называется WASB - Windows Azure Storage Blob. Это специальное хранилище бинарных данных, в которое можно загрузить произвольное количество файлов произвольного размера. Таким образом, после работы на машине, результат можно выгрузить в это хранилище и к нему будет доступ из любого другого места.
#
# Попробуем создать такое хранилище у нас в облаке.

# %%
# %%writefile blob.tf
# # Аккаунт хранения
# resource "azurerm_storage_account" "lsml_sa" {
#   name = "lsmlstorage"
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#   location = azurerm_resource_group.lsml_rg.location
#   account_tier = "Standard"
#   account_replication_type = "LRS"
#   allow_blob_public_access = true
#   # По умолчанию доступ только приватный. Добавим публичный доступ.
# }
#
# # Контейнер внутри WASB
# resource "azurerm_storage_container" "lsml_sc" {
#   name = "content"
#   # Как наш контейнер с данными будет называться
#   storage_account_name = azurerm_storage_account.lsml_sa.name
#   container_access_type = "blob"
# }
#
#
# # По умолчанию у основного пользователя ограниченные права на работу с WASB.
# # Выдадим доступ уровня "Storage Blob Data Contributor"
# # data "azurerm_subscription" "primary" {
# # }
#
# # data "azurerm_client_config" "example" {
# # }
#
# # resource "azurerm_role_assignment" "example" {
# #   scope = data.azurerm_subscription.primary.id
# #   principal_id = data.azurerm_client_config.example.object_id
#
# #   role_definition_name = "Storage Blob Data Contributor"
# # }
# Out:
# Overwriting blob.tf

# %%
! echo "yes" | terraform apply
# Out:
# azurerm_resource_group.lsml_rg: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group]
# azurerm_public_ip.lsml_pub_ip: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip]
# azurerm_virtual_network.lsml_vn: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network]
# azurerm_storage_account.lsml_sa: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Storage/storageAccounts/lsmlstorage]
# azurerm_subnet.lsml_subnet: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network/subnets/internal]
# azurerm_network_interface.lsml_ni: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/networkInterfaces/lsml-nic]
# azurerm_virtual_machine.lsml_vm: Refreshing state... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Compute/virtualMachines/lsml-machine]
# azurerm_storage_container.lsml_sc: Refreshing state... [id=https://lsmlstorage.blob.core.windows.net/content]
#
# Warning: Version constraints inside provider configuration blocks are deprecated
#
#   on common.tf line 6, in provider "azurerm":
#    6:   version = "=2.40.0"
#
# Terraform 0.13 and earlier allowed provider version constraints inside the
# provider configuration block, but that is now deprecated and will be removed
# in a future version of Terraform. To silence this warning, move the provider
# version constraint into the required_providers block.
#
#
# Apply complete! Resources: 0 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# private_ip = "10.0.2.4"
# public_domain = "alexlsmlmachine.westus.cloudapp.azure.com"
# public_ip = "13.91.45.230"

# %% [markdown]
# Для работы с хранилищем можно использовать утилиту `az`, которую мы рассматривали выше.
# Попробуем загрузить какой-то файл в наше облако. Так как мы выдали публичный доступ до нашего контейнера, то этот файл будет сразу же доступ всем в интернете.

# %%
! az login
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CGXUCU28F to authenticate.
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "21f26c24-0793-4b07-a73d-563cd2ec235f",
#     "id": "7d1225ca-27cc-40b7-8036-c62a48072ba8",
#     "isDefault": true,
#     "managedByTenants": [],
#     "name": "Спонсорское предложение Microsoft Azure 2",
#     "state": "Enabled",
#     "tenantId": "21f26c24-0793-4b07-a73d-563cd2ec235f",
#     "user": {
#       "name": "adkosmachev@edu.hse.ru",
#       "type": "user"
#     }
#   }
# ]

# %%
# %%writefile file.txt
# THIS IS MY FILE!
# Out:
# Writing file.txt

# %%
! cat file.txt
# Out:
# THIS IS MY FILE!

# %%
! az storage blob upload --account-name lsmlstorage --container-name content --file file.txt --name file-in-cloud.txt
# Out:
# There are no credentials provided in your command and environment, we will query for the account key inside your storage account.
# Please provide --connection-string, --account-key or --sas-token as credentials, or use `--auth-mode login` if you have required RBAC roles in your command. For more information about RBAC roles in storage, visit https://docs.microsoft.com/en-us/azure/storage/common/storage-auth-aad-rbac-cli.
# Setting the corresponding environment variables can avoid inputting credentials in your command. Please use --help to get more information.
# Finished[#############################################################]  100.0000%
# {
#   "etag": "\"0x8D8B7C1D68638A3\"",
#   "lastModified": "2021-01-13T12:50:42+00:00"
# }

# %%
! az storage blob list --account-name lsmlstorage --container-name content
# Out:
# There are no credentials provided in your command and environment, we will query for the account key inside your storage account.
# Please provide --connection-string, --account-key or --sas-token as credentials, or use `--auth-mode login` if you have required RBAC roles in your command. For more information about RBAC roles in storage, visit https://docs.microsoft.com/en-us/azure/storage/common/storage-auth-aad-rbac-cli.
# Setting the corresponding environment variables can avoid inputting credentials in your command. Please use --help to get more information.
# [
#   {
#     "container": "content",
#     "content": "",
#     "deleted": null,
#     "encryptedMetadata": null,
#     "encryptionKeySha256": null,
#     "encryptionScope": null,
#     "isAppendBlobSealed": null,
#     "isCurrentVersion": null,
#     "metadata": {},
#     "name": "file-in-cloud.txt",
#     "objectReplicationDestinationPolicy": null,
#     "objectReplicationSourceProperties": [],
#     "properties": {
#       "appendBlobCommittedBlockCount": null,
#       "blobTier": "Hot",
#       "blobTierChangeTime": null,
#       "blobTierInferred": true,
#       "blobType": "BlockBlob",
#       "contentLength": 17,
#       "contentRange": null,
#       "contentSettings": {
#         "cacheControl": null,
#         "contentDisposition": null,
#         "contentEncoding": null,
#         "contentLanguage": null,
#         "contentMd5": "xzTbrZpCLy7h64I8F8Vjkw==",
#         "contentType": "text/plain"
#       },
#       "copy": {
#         "completionTime": null,
#         "destinationSnapshot": null,
#         "id": null,
#         "incrementalCopy": null,
#         "progress": null,
#         "source": null,
#         "status": null,
#         "statusDescription": null
#       },
#       "creationTime": "2021-01-13T12:50:42+00:00",
#       "deletedTime": null,
#       "etag": "0x8D8B7C1D68638A3",
#       "lastModified": "2021-01-13T12:50:42+00:00",
#       "lease": {
#         "duration": null,
#         "state": "available",
#         "status": "unlocked"
#       },
#       "pageBlobSequenceNumber": null,
#       "pageRanges": null,
#       "rehydrationStatus": null,
#       "remainingRetentionDays": null,
#       "serverEncrypted": true
#     },
#     "rehydratePriority": null,
#     "requestServerEncrypted": null,
#     "snapshot": null,
#     "tagCount": null,
#     "tags": null,
#     "versionId": null
#   },
#   {
#     "container": "content",
#     "content": "",
#     "deleted": null,
#     "encryptedMetadata": null,
#     "encryptionKeySha256": null,
#     "encryptionScope": null,
#     "isAppendBlobSealed": null,
#     "isCurrentVersion": null,
#     "metadata": {},
#     "name": "КОТ84%.png",
#     "objectReplicationDestinationPolicy": null,
#     "objectReplicationSourceProperties": [],
#     "properties": {
#       "appendBlobCommittedBlockCount": null,
#       "blobTier": "Hot",
#       "blobTierChangeTime": null,
#       "blobTierInferred": true,
#       "blobType": "BlockBlob",
#       "contentLength": 242454,
#       "contentRange": null,
#       "contentSettings": {
#         "cacheControl": null,
#         "contentDisposition": null,
#         "contentEncoding": null,
#         "contentLanguage": null,
#         "contentMd5": "FWh+ogh582/R2A/27v1P+w==",
#         "contentType": "image/png"
#       },
#       "copy": {
#         "completionTime": null,
#         "destinationSnapshot": null,
#         "id": null,
#         "incrementalCopy": null,
#         "progress": null,
#         "source": null,
#         "status": null,
#         "statusDescription": null
#       },
#       "creationTime": "2021-01-13T12:48:58+00:00",
#       "deletedTime": null,
#       "etag": "0x8D8B7C198386DFF",
#       "lastModified": "2021-01-13T12:48:58+00:00",
#       "lease": {
#         "duration": null,
#         "state": "available",
#         "status": "unlocked"
#       },
#       "pageBlobSequenceNumber": null,
#       "pageRanges": null,
#       "rehydrationStatus": null,
#       "remainingRetentionDays": null,
#       "serverEncrypted": true
#     },
#     "rehydratePriority": null,
#     "requestServerEncrypted": null,
#     "snapshot": null,
#     "tagCount": null,
#     "tags": null,
#     "versionId": null
#   }
# ]

# %%
! wget https://lsmlstorage.blob.core.windows.net/content/file-in-cloud.txt
# Out:
# --2021-01-13 12:52:45--  https://lsmlstorage.blob.core.windows.net/content/file-in-cloud.txt
# Resolving lsmlstorage.blob.core.windows.net (lsmlstorage.blob.core.windows.net)... 20.150.34.228
# Connecting to lsmlstorage.blob.core.windows.net (lsmlstorage.blob.core.windows.net)|20.150.34.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17 [text/plain]
# Saving to: ‘file-in-cloud.txt’
#
# file-in-cloud.txt   100%[===================>]      17  --.-KB/s    in 0s
#
# 2021-01-13 12:52:46 (5.08 MB/s) - ‘file-in-cloud.txt’ saved [17/17]

# %%
! cat file-in-cloud.txt
# Out:
# THIS IS MY FILE!

# %% [markdown]
# Таким образом мы умеет работать загружать файлы в облако и выгрузать их оттуда.
#
# Вместо публичного доступа, можно оставить только приватный и получать файлы тоже через `az`

# %%
! az storage blob download --account-name lsmlstorage --container-name content --file file-from-az.txt --name file-in-cloud.txt
# Out:
# There are no credentials provided in your command and environment, we will query for the account key inside your storage account.
# Please provide --connection-string, --account-key or --sas-token as credentials, or use `--auth-mode login` if you have required RBAC roles in your command. For more information about RBAC roles in storage, visit https://docs.microsoft.com/en-us/azure/storage/common/storage-auth-aad-rbac-cli.
# Setting the corresponding environment variables can avoid inputting credentials in your command. Please use --help to get more information.
# Finished[#############################################################]  100.0000%
# {
#   "content": null,
#   "deleted": false,
#   "metadata": {},
#   "name": "file-in-cloud.txt",
#   "properties": {
#     "appendBlobCommittedBlockCount": null,
#     "blobTier": null,
#     "blobTierChangeTime": null,
#     "blobTierInferred": false,
#     "blobType": "BlockBlob",
#     "contentLength": 17,
#     "contentRange": "bytes 0-16/17",
#     "contentSettings": {
#       "cacheControl": null,
#       "contentDisposition": null,
#       "contentEncoding": null,
#       "contentLanguage": null,
#       "contentMd5": "xzTbrZpCLy7h64I8F8Vjkw==",
#       "contentType": "text/plain"
#     },
#     "copy": {
#       "completionTime": null,
#       "id": null,
#       "progress": null,
#       "source": null,
#       "status": null,
#       "statusDescription": null
#     },
#     "creationTime": "2021-01-06T12:26:08+00:00",
#     "deletedTime": null,
#     "etag": "\"0x8D8B23E3E9CE8F3\"",
#     "lastModified": "2021-01-06T12:26:08+00:00",
#     "lease": {
#       "duration": null,
#       "state": "available",
#       "status": "unlocked"
#     },
#     "pageBlobSequenceNumber": null,
#     "remainingRetentionDays": null,
#     "serverEncrypted": true
#   },
#   "snapshot": null
# }

# %%
! cat file-from-az.txt
# Out:
# THIS IS MY FILE!

# %% [markdown]
# Если файлов значительно больше чем 1, то можно воспользоваться утилитой azcopy. Она умеет синхронизировать сразу целые директории между облаком и локальным диском.

# %%
! wget -O azcopy_v10.tar.gz https://aka.ms/downloadazcopy-v10-linux && tar -xf azcopy_v10.tar.gz --strip-components=1
# Out:
# --2021-01-13 12:54:17--  https://aka.ms/downloadazcopy-v10-linux
# Resolving aka.ms (aka.ms)... 23.53.53.76
# Connecting to aka.ms (aka.ms)|23.53.53.76|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://azcopyvnext.azureedge.net/release20201211/azcopy_linux_amd64_10.8.0.tar.gz [following]
# --2021-01-13 12:54:17--  https://azcopyvnext.azureedge.net/release20201211/azcopy_linux_amd64_10.8.0.tar.gz
# Resolving azcopyvnext.azureedge.net (azcopyvnext.azureedge.net)... 212.188.39.162, 212.188.39.208, 2a02:28:1:31::d4bc:278b, ...
# Connecting to azcopyvnext.azureedge.net (azcopyvnext.azureedge.net)|212.188.39.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9367788 (8.9M) [application/gzip]
# Saving to: ‘azcopy_v10.tar.gz’
#
# azcopy_v10.tar.gz   100%[===================>]   8.93M  24.4MB/s    in 0.4s
#
# 2021-01-13 12:54:18 (24.4 MB/s) - ‘azcopy_v10.tar.gz’ saved [9367788/9367788]

# %%
! mkdir -p big-folder
! echo file1 > big-folder/file1.txt
! echo file2 > big-folder/file2.txt
! echo file3 > big-folder/file3.txt

# %%
! ls big-folder/
# Out:
# file1.txt  file2.txt  file3.txt

# %% [markdown]
# Из-за особенностей устройства azcopy, команды ниже не работают внутри Docker. Если вам это ничего не говорит, то можете не беспокоиться и просто запускать команды. Если же вы запускаете их в ноутбуке из под Docker (как это люблю делать я), то просто делайте это вне Docker окружения.

# %%
! ./azcopy login
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code DDCVKFBQX to authenticate.
#
# INFO: Logging in under the "Common" tenant. This will log the account in under its home tenant.
# INFO: If you plan to use AzCopy with a B2B account (where the account's home tenant is separate from the tenant of the target storage account), please sign in under the target tenant with --tenant-id
#
# Failed to perform login command:
# failed to get keyring during saving token, operation not permitted
#
# NOTE: If your credential was created in the last 5 minutes, please wait a few minutes and try again.

# %%
! ./azcopy sync big-folder/ https://lsmlstorage.blob.core.windows.net/content/big-folder-in-cloud --recursive
# Out:
# Cannot perform sync due to error: Login Credentials missing. No SAS token or OAuth token is present and the resource is not public

# %%
! wget https://lsmlstorage.blob.core.windows.net/content/big-folder-in-cloud/file1.txt
# Out:
# --2021-01-06 12:40:39--  https://lsmlstorage.blob.core.windows.net/content/big-folder-in-cloud/file1.txt
# Resolving lsmlstorage.blob.core.windows.net (lsmlstorage.blob.core.windows.net)... 52.239.162.4
# Connecting to lsmlstorage.blob.core.windows.net (lsmlstorage.blob.core.windows.net)|52.239.162.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6 [text/plain]
# Saving to: ‘file1.txt’
#
# file1.txt           100%[===================>]       6  --.-KB/s    in 0s
#
# 2021-01-06 12:40:40 (1.37 MB/s) - ‘file1.txt’ saved [6/6]

# %%
! mkdir new-folder

# %%
! ./azcopy sync https://lsmlstorage.blob.core.windows.net/content/big-folder-in-cloud new-folder/ --recursive

# %% [markdown]
# ### Выключайте ресурсы!
#
# Использование облака - дело не самое дешевое. Поэтому после работы в облаке, сохраните свой результат и отключите вычислительные ресурсы.
#
# <img src="https://avatars.mds.yandex.net/get-zen_doc/27036/pub_5b7714d46cf6c700aa7e06f7_5b7714d99dce6b00aa88d3f6/scale_1200">
#
# Это можно сделать как минимум тремя способами:
# 1. Выключить машины руками через браузер
# 2. Удалить\закоментировать ненужные ресурсы в конфигурации terraform и применить `terraform apply`
# 3. Точечно удалять ресурсы через `terraform destroy -target <target>`. Например, `terraform destroy -target azurerm_virtual_machine.lsml_vm` точечно убьет машину в облаке. После повторного применения `terraform apply` она вновь появится.
#
# **Не запускайте `terraform destroy` не подумав!** Эта команда уничтожит все ресурсы в облаке, **включая хранилище данных, где могут быть ценные для вас файлы**.
#
# Следите за уровнем доступных вам кредитов и за количеством арендованных ресурсов, чтобы их хватило на все работы в рамках курса!

# %%
! cat vm.tf
# Out:
# # Здесь описываем ресурсы, необходимые для работы машины
#
# # Публичный адрес машины
# resource "azurerm_public_ip" "lsml_pub_ip" {
#   location = azurerm_resource_group.lsml_rg.location
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#
#   name = "lsml-public-ip"
#
#   allocation_method = "Dynamic" # Выдаем динамический ip
#   idle_timeout_in_minutes = 30
#   domain_name_label = "alexlsmlmachine" # Для удобства можно использовать DNS имя
# }
#
# # Сетевой интерфейс для нашей машины
# resource "azurerm_network_interface" "lsml_ni" {
#   location = azurerm_resource_group.lsml_rg.location
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#
#   name = "lsml-nic"
#
#   ip_configuration {
#     name = "internal"
#     private_ip_address_allocation = "Dynamic"
#     subnet_id = azurerm_subnet.lsml_subnet.id
#     public_ip_address_id = azurerm_public_ip.lsml_pub_ip.id
#   }
# }
#
# # Сама виртуальная машина
# resource "azurerm_virtual_machine" "lsml_vm" {
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#   location = azurerm_resource_group.lsml_rg.location
#
#   name = "lsml-machine"
#
#   vm_size = "Standard_F2" # 2 CPU 4 GB
#   # Какие размеры вообще бывают - https://azure.microsoft.com/en-us/pricing/details/virtual-machines/series/
#
#   network_interface_ids = [
#     azurerm_network_interface.lsml_ni.id,
#     # Подключаем к сети
#   ]
#
#   storage_image_reference {
#     # Используем образ Ubuntu 16.04
#     publisher = "Canonical"
#     offer = "UbuntuServer"
#     sku = "16.04-LTS"
#     version = "latest"
#   }
#
#   os_profile {
#     computer_name = "hostname"
#     admin_username = "azureuser" # Пользователь и его пароль
#     admin_password = "Password1234!"
#   }
#   os_profile_linux_config {
#     disable_password_authentication = false
#     ssh_keys {
#       path = "/home/azureuser/.ssh/authorized_keys"
#       key_data = file("~/id_rsa.pub") # Можем указать наш ключ, как ключ для авторизации на машине
#     }
#   }
#
#   delete_os_disk_on_termination = true
#   storage_os_disk {
#     name = "main-disk"
#     caching = "ReadWrite"
#     create_option = "FromImage"
#     managed_disk_type = "Standard_LRS"
#     disk_size_gb = "200" # Указываем какой использовать основной жесткий диск и его размер
#   }
# }
#
#
# # Созраним несколько важный значений в output. Их можно будет потом использовать для наших целей
#
# data "azurerm_public_ip" "lsml_public_ip" {
#   name = azurerm_public_ip.lsml_pub_ip.name
#   resource_group_name = azurerm_virtual_machine.lsml_vm.resource_group_name
# }
#
# output "public_domain" {
#   # Домен нашего сервера
#   value = "${azurerm_public_ip.lsml_pub_ip.domain_name_label}.${azurerm_resource_group.lsml_rg.location}.cloudapp.azure.com"
# }
#
# output "public_ip" {
#   # Публичный ip нашего сервера
#   value = data.azurerm_public_ip.lsml_public_ip.ip_address
# }
#
# output "private_ip" {
#   # Приватный ip нашего сервера
#   value = azurerm_network_interface.lsml_ni.private_ip_address
# }

# %%
# %%writefile vm.tf
# # Здесь описываем ресурсы, необходимые для работы машины
#
# # Публичный адрес машины
# resource "azurerm_public_ip" "lsml_pub_ip" {
#   location = azurerm_resource_group.lsml_rg.location
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#
#   name = "lsml-public-ip"
#
#   allocation_method = "Dynamic" # Выдаем динамический ip
#   idle_timeout_in_minutes = 30
#   domain_name_label = "alexlsmlmachine" # Для удобства можно использовать DNS имя
# }
#
# # Сетевой интерфейс для нашей машины
# resource "azurerm_network_interface" "lsml_ni" {
#   location = azurerm_resource_group.lsml_rg.location
#   resource_group_name = azurerm_resource_group.lsml_rg.name
#
#   name = "lsml-nic"
#
#   ip_configuration {
#     name = "internal"
#     private_ip_address_allocation = "Dynamic"
#     subnet_id = azurerm_subnet.lsml_subnet.id
#     public_ip_address_id = azurerm_public_ip.lsml_pub_ip.id
#   }
# }
#
# # # Сама виртуальная машина
# # resource "azurerm_virtual_machine" "lsml_vm" {
# #   resource_group_name = azurerm_resource_group.lsml_rg.name
# #   location = azurerm_resource_group.lsml_rg.location
#
# #   name = "lsml-machine"
#
# #   vm_size = "Standard_F2" # 2 CPU 4 GB
# #   # Какие размеры вообще бывают - https://azure.microsoft.com/en-us/pricing/details/virtual-machines/series/
#
# #   network_interface_ids = [
# #     azurerm_network_interface.lsml_ni.id,
# #     # Подключаем к сети
# #   ]
#
# #   storage_image_reference {
# #     # Используем образ Ubuntu 16.04
# #     publisher = "Canonical"
# #     offer = "UbuntuServer"
# #     sku = "16.04-LTS"
# #     version = "latest"
# #   }
#
# #   os_profile {
# #     computer_name = "hostname"
# #     admin_username = "azureuser" # Пользователь и его пароль
# #     admin_password = "Password1234!"
# #   }
# #   os_profile_linux_config {
# #     disable_password_authentication = false
# #     ssh_keys {
# #       path = "/home/azureuser/.ssh/authorized_keys"
# #       key_data = file("~/id_rsa.pub") # Можем указать наш ключ, как ключ для авторизации на машине
# #     }
# #   }
#
# #   delete_os_disk_on_termination = true
# #   storage_os_disk {
# #     name = "main-disk"
# #     caching = "ReadWrite"
# #     create_option = "FromImage"
# #     managed_disk_type = "Standard_LRS"
# #     disk_size_gb = "200" # Указываем какой использовать основной жесткий диск и его размер
# #   }
# # }
#
#
# # # Созраним несколько важный значений в output. Их можно будет потом использовать для наших целей
#
# # data "azurerm_public_ip" "lsml_public_ip" {
# #   name = azurerm_public_ip.lsml_pub_ip.name
# #   resource_group_name = azurerm_virtual_machine.lsml_vm.resource_group_name
# # }
#
# # output "public_domain" {
# #   # Домен нашего сервера
# #   value = "${azurerm_public_ip.lsml_pub_ip.domain_name_label}.${azurerm_resource_group.lsml_rg.location}.cloudapp.azure.com"
# # }
#
# # output "public_ip" {
# #   # Публичный ip нашего сервера
# #   value = data.azurerm_public_ip.lsml_public_ip.ip_address
# # }
#
# # output "private_ip" {
# #   # Приватный ip нашего сервера
# #   value = azurerm_network_interface.lsml_ni.private_ip_address
# # }
# Out:
# Overwriting vm.tf

# %%
! echo "yes" | terraform destroy
# Out:
# An execution plan has been generated and is shown below.
# Resource actions are indicated with the following symbols:
#   - destroy
#
# Terraform will perform the following actions:
#
#   # azurerm_network_interface.lsml_ni will be destroyed
#   - resource "azurerm_network_interface" "lsml_ni" {
#       - applied_dns_servers           = [] -> null
#       - dns_servers                   = [] -> null
#       - enable_accelerated_networking = false -> null
#       - enable_ip_forwarding          = false -> null
#       - id                            = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/networkInterfaces/lsml-nic" -> null
#       - internal_domain_name_suffix   = "2kfcj2iu45dephzegvk5ose2uc.dx.internal.cloudapp.net" -> null
#       - location                      = "westus" -> null
#       - mac_address                   = "00-0D-3A-36-93-5F" -> null
#       - name                          = "lsml-nic" -> null
#       - private_ip_address            = "10.0.2.4" -> null
#       - private_ip_addresses          = [
#           - "10.0.2.4",
#         ] -> null
#       - resource_group_name           = "lsml-resource-group" -> null
#       - tags                          = {} -> null
#       - virtual_machine_id            = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Compute/virtualMachines/lsml-machine" -> null
#
#       - ip_configuration {
#           - name                          = "internal" -> null
#           - primary                       = true -> null
#           - private_ip_address            = "10.0.2.4" -> null
#           - private_ip_address_allocation = "Dynamic" -> null
#           - private_ip_address_version    = "IPv4" -> null
#           - public_ip_address_id          = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip" -> null
#           - subnet_id                     = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network/subnets/internal" -> null
#         }
#     }
#
#   # azurerm_public_ip.lsml_pub_ip will be destroyed
#   - resource "azurerm_public_ip" "lsml_pub_ip" {
#       - allocation_method       = "Dynamic" -> null
#       - domain_name_label       = "alexlsmlmachine" -> null
#       - fqdn                    = "alexlsmlmachine.westus.cloudapp.azure.com" -> null
#       - id                      = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip" -> null
#       - idle_timeout_in_minutes = 30 -> null
#       - ip_address              = "13.91.45.230" -> null
#       - ip_version              = "IPv4" -> null
#       - location                = "westus" -> null
#       - name                    = "lsml-public-ip" -> null
#       - resource_group_name     = "lsml-resource-group" -> null
#       - sku                     = "Basic" -> null
#       - tags                    = {} -> null
#       - zones                   = [] -> null
#     }
#
#   # azurerm_resource_group.lsml_rg will be destroyed
#   - resource "azurerm_resource_group" "lsml_rg" {
#       - id       = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group" -> null
#       - location = "westus" -> null
#       - name     = "lsml-resource-group" -> null
#       - tags     = {} -> null
#     }
#
#   # azurerm_storage_account.lsml_sa will be destroyed
#   - resource "azurerm_storage_account" "lsml_sa" {
#       - access_tier                    = "Hot" -> null
#       - account_kind                   = "StorageV2" -> null
#       - account_replication_type       = "LRS" -> null
#       - account_tier                   = "Standard" -> null
#       - allow_blob_public_access       = true -> null
#       - enable_https_traffic_only      = true -> null
#       - id                             = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Storage/storageAccounts/lsmlstorage" -> null
#       - is_hns_enabled                 = false -> null
#       - location                       = "westus" -> null
#       - min_tls_version                = "TLS1_0" -> null
#       - name                           = "lsmlstorage" -> null
#       - primary_access_key             = (sensitive value)
#       - primary_blob_connection_string = (sensitive value)
#       - primary_blob_endpoint          = "https://lsmlstorage.blob.core.windows.net/" -> null
#       - primary_blob_host              = "lsmlstorage.blob.core.windows.net" -> null
#       - primary_connection_string      = (sensitive value)
#       - primary_dfs_endpoint           = "https://lsmlstorage.dfs.core.windows.net/" -> null
#       - primary_dfs_host               = "lsmlstorage.dfs.core.windows.net" -> null
#       - primary_file_endpoint          = "https://lsmlstorage.file.core.windows.net/" -> null
#       - primary_file_host              = "lsmlstorage.file.core.windows.net" -> null
#       - primary_location               = "westus" -> null
#       - primary_queue_endpoint         = "https://lsmlstorage.queue.core.windows.net/" -> null
#       - primary_queue_host             = "lsmlstorage.queue.core.windows.net" -> null
#       - primary_table_endpoint         = "https://lsmlstorage.table.core.windows.net/" -> null
#       - primary_table_host             = "lsmlstorage.table.core.windows.net" -> null
#       - primary_web_endpoint           = "https://lsmlstorage.z22.web.core.windows.net/" -> null
#       - primary_web_host               = "lsmlstorage.z22.web.core.windows.net" -> null
#       - resource_group_name            = "lsml-resource-group" -> null
#       - secondary_access_key           = (sensitive value)
#       - secondary_connection_string    = (sensitive value)
#       - tags                           = {} -> null
#
#       - network_rules {
#           - bypass                     = [
#               - "AzureServices",
#             ] -> null
#           - default_action             = "Allow" -> null
#           - ip_rules                   = [] -> null
#           - virtual_network_subnet_ids = [] -> null
#         }
#
#       - queue_properties {
#
#           - hour_metrics {
#               - enabled               = true -> null
#               - include_apis          = true -> null
#               - retention_policy_days = 7 -> null
#               - version               = "1.0" -> null
#             }
#
#           - logging {
#               - delete                = false -> null
#               - read                  = false -> null
#               - retention_policy_days = 0 -> null
#               - version               = "1.0" -> null
#               - write                 = false -> null
#             }
#
#           - minute_metrics {
#               - enabled               = false -> null
#               - include_apis          = false -> null
#               - retention_policy_days = 0 -> null
#               - version               = "1.0" -> null
#             }
#         }
#     }
#
#   # azurerm_storage_container.lsml_sc will be destroyed
#   - resource "azurerm_storage_container" "lsml_sc" {
#       - container_access_type   = "blob" -> null
#       - has_immutability_policy = false -> null
#       - has_legal_hold          = false -> null
#       - id                      = "https://lsmlstorage.blob.core.windows.net/content" -> null
#       - metadata                = {} -> null
#       - name                    = "content" -> null
#       - resource_manager_id     = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Storage/storageAccounts/lsmlstorage/blobServices/default/containers/content" -> null
#       - storage_account_name    = "lsmlstorage" -> null
#     }
#
#   # azurerm_subnet.lsml_subnet will be destroyed
#   - resource "azurerm_subnet" "lsml_subnet" {
#       - address_prefix                                 = "10.0.2.0/24" -> null
#       - address_prefixes                               = [
#           - "10.0.2.0/24",
#         ] -> null
#       - enforce_private_link_endpoint_network_policies = false -> null
#       - enforce_private_link_service_network_policies  = false -> null
#       - id                                             = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network/subnets/internal" -> null
#       - name                                           = "internal" -> null
#       - resource_group_name                            = "lsml-resource-group" -> null
#       - service_endpoints                              = [] -> null
#       - virtual_network_name                           = "lsml-vitrual-network" -> null
#     }
#
#   # azurerm_virtual_machine.lsml_vm will be destroyed
#   - resource "azurerm_virtual_machine" "lsml_vm" {
#       - delete_data_disks_on_termination = false -> null
#       - delete_os_disk_on_termination    = true -> null
#       - id                               = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Compute/virtualMachines/lsml-machine" -> null
#       - location                         = "westus" -> null
#       - name                             = "lsml-machine" -> null
#       - network_interface_ids            = [
#           - "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/networkInterfaces/lsml-nic",
#         ] -> null
#       - resource_group_name              = "lsml-resource-group" -> null
#       - tags                             = {} -> null
#       - vm_size                          = "Standard_F2" -> null
#       - zones                            = [] -> null
#
#       - os_profile {
#           - admin_username = "azureuser" -> null
#           - computer_name  = "hostname" -> null
#         }
#
#       - os_profile_linux_config {
#           - disable_password_authentication = false -> null
#
#           - ssh_keys {
#               - key_data = <<-EOT
#                     ssh-rsa ... kosmos@neatsy.ai
#                 EOT -> null
#               - path     = "/home/azureuser/.ssh/authorized_keys" -> null
#             }
#         }
#
#       - storage_image_reference {
#           - offer     = "UbuntuServer" -> null
#           - publisher = "Canonical" -> null
#           - sku       = "16.04-LTS" -> null
#           - version   = "latest" -> null
#         }
#
#       - storage_os_disk {
#           - caching                   = "ReadWrite" -> null
#           - create_option             = "FromImage" -> null
#           - disk_size_gb              = 200 -> null
#           - managed_disk_id           = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Compute/disks/main-disk" -> null
#           - managed_disk_type         = "Standard_LRS" -> null
#           - name                      = "main-disk" -> null
#           - os_type                   = "Linux" -> null
#           - write_accelerator_enabled = false -> null
#         }
#     }
#
#   # azurerm_virtual_network.lsml_vn will be destroyed
#   - resource "azurerm_virtual_network" "lsml_vn" {
#       - address_space         = [
#           - "10.0.0.0/16",
#         ] -> null
#       - dns_servers           = [] -> null
#       - guid                  = "f1248ae2-f714-47c6-9f24-3555f7489ca2" -> null
#       - id                    = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network" -> null
#       - location              = "westus" -> null
#       - name                  = "lsml-vitrual-network" -> null
#       - resource_group_name   = "lsml-resource-group" -> null
#       - subnet                = [
#           - {
#               - address_prefix = "10.0.2.0/24"
#               - id             = "/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network/subnets/internal"
#               - name           = "internal"
#               - security_group = ""
#             },
#         ] -> null
#       - tags                  = {} -> null
#       - vm_protection_enabled = false -> null
#     }
#
# Plan: 0 to add, 0 to change, 8 to destroy.
#
#
# Warning: Version constraints inside provider configuration blocks are deprecated
#
#   on common.tf line 6, in provider "azurerm":
#    6:   version = "=2.40.0"
#
# Terraform 0.13 and earlier allowed provider version constraints inside the
# provider configuration block, but that is now deprecated and will be removed
# in a future version of Terraform. To silence this warning, move the provider
# version constraint into the required_providers block.
#
# Do you really want to destroy all resources?
#   Terraform will destroy all your managed infrastructure, as shown above.
#   There is no undo. Only 'yes' will be accepted to confirm.
#
#   Enter a value:
# azurerm_storage_container.lsml_sc: Destroying... [id=https://lsmlstorage.blob.core.windows.net/content]
# azurerm_virtual_machine.lsml_vm: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Compute/virtualMachines/lsml-machine]
# azurerm_storage_container.lsml_sc: Destruction complete after 3s
# azurerm_storage_account.lsml_sa: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Storage/storageAccounts/lsmlstorage]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 10s elapsed]
# azurerm_storage_account.lsml_sa: Destruction complete after 9s
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 20s elapsed]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 30s elapsed]
# azurerm_virtual_machine.lsml_vm: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...t.Compute/virtualMachines/lsml-machine, 40s elapsed]
# azurerm_virtual_machine.lsml_vm: Destruction complete after 47s
# azurerm_network_interface.lsml_ni: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/networkInterfaces/lsml-nic]
# azurerm_network_interface.lsml_ni: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...oft.Network/networkInterfaces/lsml-nic, 10s elapsed]
# azurerm_network_interface.lsml_ni: Destruction complete after 13s
# azurerm_public_ip.lsml_pub_ip: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/publicIPAddresses/lsml-public-ip]
# azurerm_subnet.lsml_subnet: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network/subnets/internal]
# azurerm_public_ip.lsml_pub_ip: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...twork/publicIPAddresses/lsml-public-ip, 10s elapsed]
# azurerm_subnet.lsml_subnet: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-.../lsml-vitrual-network/subnets/internal, 10s elapsed]
# azurerm_subnet.lsml_subnet: Destruction complete after 12s
# azurerm_virtual_network.lsml_vn: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group/providers/Microsoft.Network/virtualNetworks/lsml-vitrual-network]
# azurerm_public_ip.lsml_pub_ip: Destruction complete after 12s
# azurerm_virtual_network.lsml_vn: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...k/virtualNetworks/lsml-vitrual-network, 10s elapsed]
# azurerm_virtual_network.lsml_vn: Destruction complete after 11s
# azurerm_resource_group.lsml_rg: Destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-c62a48072ba8/resourceGroups/lsml-resource-group]
# azurerm_resource_group.lsml_rg: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...ba8/resourceGroups/lsml-resource-group, 10s elapsed]
# azurerm_resource_group.lsml_rg: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...ba8/resourceGroups/lsml-resource-group, 20s elapsed]
# azurerm_resource_group.lsml_rg: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...ba8/resourceGroups/lsml-resource-group, 30s elapsed]
# azurerm_resource_group.lsml_rg: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...ba8/resourceGroups/lsml-resource-group, 40s elapsed]
# azurerm_resource_group.lsml_rg: Still destroying... [id=/subscriptions/7d1225ca-27cc-40b7-8036-...ba8/resourceGroups/lsml-resource-group, 50s elapsed]
# azurerm_resource_group.lsml_rg: Destruction complete after 50s
#
# Destroy complete! Resources: 8 destroyed.
